# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings

warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "virny-flow-experiments":
    os.chdir("../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/Research/NYU/VirnyFlow_Project/Code/virny-flow-experiments

# %% [markdown]
# # Case Studies Visualizations

# %%
from source.visualizations.use_case_queries import get_best_lps_per_exp_config
from source.visualizations.cost_model_viz import create_box_plot_per_dataset_and_case_study

# %% [markdown]
# ## Prepare data for visualizations

# %%
SECRETS_PATH = os.path.join(os.getcwd(), "scripts", "configs", "secrets.env")
GROUP = "Gender"
EXP_CONFIG_NAMES = [
    "test_case_studies_exp_diabetes_cs1_w_acc_0_25_w_fair_0_75",
    "test_case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair_0_5",
    "test_case_studies_exp_diabetes_cs1_w_acc_0_75_w_fair_0_25",
    "test_case_studies_exp_diabetes_cs2_w_acc_0_5_w_stab_0_5",
]

# %%
best_lp_metrics_per_exp_config_df = get_best_lps_per_exp_config(secrets_path=SECRETS_PATH, exp_config_names=EXP_CONFIG_NAMES)
# Out:
# Extracting metrics for test_case_studies_exp_diabetes_cs1_w_acc_0_25_w_fair_0_75...
# best_pps_per_lp_and_run_num_df.shape: (18, 15)
# max_lp_avg_compound_pp_quality: 0.8139433030737379
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# Extracted metrics for test_case_studies_exp_diabetes_cs1_w_acc_0_25_w_fair_0_75
#
# Extracting metrics for test_case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair_0_5...
# best_pps_per_lp_and_run_num_df.shape: (18, 15)
# max_lp_avg_compound_pp_quality: 0.8739959839357427
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZGFsZl9jbGY=
# Extracted metrics for test_case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair_0_5
#
# Extracting metrics for test_case_studies_exp_diabetes_cs1_w_acc_0_75_w_fair_0_25...
# best_pps_per_lp_and_run_num_df.shape: (27, 15)
# max_lp_avg_compound_pp_quality: 0.268719806763285
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZGFsZl9jbGY=
# Extracted metrics for test_case_studies_exp_diabetes_cs1_w_acc_0_75_w_fair_0_25
#
# Extracting metrics for test_case_studies_exp_diabetes_cs2_w_acc_0_5_w_stab_0_5...
# best_pps_per_lp_and_run_num_df.shape: (54, 15)
# max_lp_avg_compound_pp_quality: 0.870514705882353
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# Extracted metrics for test_case_studies_exp_diabetes_cs2_w_acc_0_5_w_stab_0_5

# %%
best_lp_metrics_per_exp_config_df.shape
# Out:
# (45, 15)

# %%
best_lp_metrics_per_exp_config_df.head()
# Out:
# subgroup                                    exp_config_name  \
# 9         test_case_studies_exp_diabetes_cs1_w_acc_0_25_...
# 10        test_case_studies_exp_diabetes_cs1_w_acc_0_25_...
# 11        test_case_studies_exp_diabetes_cs1_w_acc_0_25_...
# 12        test_case_studies_exp_diabetes_cs1_w_acc_0_25_...
# 13        test_case_studies_exp_diabetes_cs1_w_acc_0_25_...
#
# subgroup                             logical_pipeline_uuid  \
# 9         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 10        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 11        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 12        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 13        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
#
# subgroup                physical_pipeline_uuid  run_num  compound_pp_quality  \
# 9         a48af45e-306f-4865-b778-f9ae090c6e5d        1             0.813943
# 10        a48af45e-306f-4865-b778-f9ae090c6e5d        1             0.813943
# 11        a48af45e-306f-4865-b778-f9ae090c6e5d        1             0.813943
# 12        a48af45e-306f-4865-b778-f9ae090c6e5d        1             0.813943
# 13        a48af45e-306f-4865-b778-f9ae090c6e5d        1             0.813943
#
# subgroup    metric model_name  runtime_in_mins dataset_name  \
# 9         Accuracy     rf_clf          0.01334     diabetes
# 10              F1     rf_clf          0.01334     diabetes
# 11             FNR     rf_clf          0.01334     diabetes
# 12             FPR     rf_clf          0.01334     diabetes
# 13             PPV     rf_clf          0.01334     diabetes
#
# subgroup                 logical_pipeline_name null_imputer_name  \
# 9         None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 10        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 11        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 12        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 13        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
#
# subgroup fairness_intervention_name  Gender_dis  Gender_priv   overall
# 9          NO_FAIRNESS_INTERVENTION    0.935185     0.865854  0.893382
# 10         NO_FAIRNESS_INTERVENTION    0.898551     0.760870  0.819876
# 11         NO_FAIRNESS_INTERVENTION    0.138889     0.326923  0.250000
# 12         NO_FAIRNESS_INTERVENTION    0.027778     0.044643  0.038043
# 13         NO_FAIRNESS_INTERVENTION    0.939394     0.875000  0.904110

# %% [markdown]
# ## Create visualizations

# %% [markdown]
# ### Overall metrics

# %%
EXP_NAME = 'test_case_studies_exp'
DATASET_NAME = 'diabetes'
CASE_STUDY_NAME = 'cs1'

to_plot = best_lp_metrics_per_exp_config_df
to_plot[(to_plot['dataset_name'] == DATASET_NAME) & (to_plot['exp_config_name'].str.contains(CASE_STUDY_NAME, case=False, na=False))]
# Out:
# subgroup                                    exp_config_name  \
# 9         test_case_studies_exp_diabetes_cs1_w_acc_0_25_...
# 10        test_case_studies_exp_diabetes_cs1_w_acc_0_25_...
# 11        test_case_studies_exp_diabetes_cs1_w_acc_0_25_...
# 12        test_case_studies_exp_diabetes_cs1_w_acc_0_25_...
# 13        test_case_studies_exp_diabetes_cs1_w_acc_0_25_...
# 14        test_case_studies_exp_diabetes_cs1_w_acc_0_25_...
# 15        test_case_studies_exp_diabetes_cs1_w_acc_0_25_...
# 16        test_case_studies_exp_diabetes_cs1_w_acc_0_25_...
# 17        test_case_studies_exp_diabetes_cs1_w_acc_0_25_...
# 0         test_case_studies_exp_diabetes_cs1_w_acc_0_5_w...
# 1         test_case_studies_exp_diabetes_cs1_w_acc_0_5_w...
# 2         test_case_studies_exp_diabetes_cs1_w_acc_0_5_w...
# 3         test_case_studies_exp_diabetes_cs1_w_acc_0_5_w...
# 4         test_case_studies_exp_diabetes_cs1_w_acc_0_5_w...
# 5         test_case_studies_exp_diabetes_cs1_w_acc_0_5_w...
# 6         test_case_studies_exp_diabetes_cs1_w_acc_0_5_w...
# 7         test_case_studies_exp_diabetes_cs1_w_acc_0_5_w...
# 8         test_case_studies_exp_diabetes_cs1_w_acc_0_5_w...
# 0         test_case_studies_exp_diabetes_cs1_w_acc_0_75_...
# 1         test_case_studies_exp_diabetes_cs1_w_acc_0_75_...
# 2         test_case_studies_exp_diabetes_cs1_w_acc_0_75_...
# 3         test_case_studies_exp_diabetes_cs1_w_acc_0_75_...
# 4         test_case_studies_exp_diabetes_cs1_w_acc_0_75_...
# 5         test_case_studies_exp_diabetes_cs1_w_acc_0_75_...
# 6         test_case_studies_exp_diabetes_cs1_w_acc_0_75_...
# 7         test_case_studies_exp_diabetes_cs1_w_acc_0_75_...
# 8         test_case_studies_exp_diabetes_cs1_w_acc_0_75_...
#
# subgroup                              logical_pipeline_uuid  \
# 9          Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 10         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 11         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 12         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 13         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 14         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 15         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 16         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 17         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 0         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 1         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 2         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 3         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 4         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 5         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 6         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 7         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 8         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 0         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 1         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 2         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 3         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 4         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 5         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 6         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 7         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 8         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
#
# subgroup                physical_pipeline_uuid  run_num  compound_pp_quality  \
# 9         a48af45e-306f-4865-b778-f9ae090c6e5d        1             0.813943
# 10        a48af45e-306f-4865-b778-f9ae090c6e5d        1             0.813943
# 11        a48af45e-306f-4865-b778-f9ae090c6e5d        1             0.813943
# 12        a48af45e-306f-4865-b778-f9ae090c6e5d        1             0.813943
# 13        a48af45e-306f-4865-b778-f9ae090c6e5d        1             0.813943
# 14        a48af45e-306f-4865-b778-f9ae090c6e5d        1             0.813943
# 15        a48af45e-306f-4865-b778-f9ae090c6e5d        1             0.813943
# 16        a48af45e-306f-4865-b778-f9ae090c6e5d        1             0.813943
# 17        a48af45e-306f-4865-b778-f9ae090c6e5d        1             0.813943
# 0         9774cefb-c453-4409-8d80-cba863d968d3        1             0.873996
# 1         9774cefb-c453-4409-8d80-cba863d968d3        1             0.873996
# 2         9774cefb-c453-4409-8d80-cba863d968d3        1             0.873996
# 3         9774cefb-c453-4409-8d80-cba863d968d3        1             0.873996
# 4         9774cefb-c453-4409-8d80-cba863d968d3        1             0.873996
# 5         9774cefb-c453-4409-8d80-cba863d968d3        1             0.873996
# 6         9774cefb-c453-4409-8d80-cba863d968d3        1             0.873996
# 7         9774cefb-c453-4409-8d80-cba863d968d3        1             0.873996
# 8         9774cefb-c453-4409-8d80-cba863d968d3        1             0.873996
# 0         d37e7762-72b6-4fb2-9c45-8c3458d79fa2        1             0.268720
# 1         d37e7762-72b6-4fb2-9c45-8c3458d79fa2        1             0.268720
# 2         d37e7762-72b6-4fb2-9c45-8c3458d79fa2        1             0.268720
# 3         d37e7762-72b6-4fb2-9c45-8c3458d79fa2        1             0.268720
# 4         d37e7762-72b6-4fb2-9c45-8c3458d79fa2        1             0.268720
# 5         d37e7762-72b6-4fb2-9c45-8c3458d79fa2        1             0.268720
# 6         d37e7762-72b6-4fb2-9c45-8c3458d79fa2        1             0.268720
# 7         d37e7762-72b6-4fb2-9c45-8c3458d79fa2        1             0.268720
# 8         d37e7762-72b6-4fb2-9c45-8c3458d79fa2        1             0.268720
#
# subgroup          metric   model_name  runtime_in_mins dataset_name  \
# 9               Accuracy       rf_clf         0.013340     diabetes
# 10                    F1       rf_clf         0.013340     diabetes
# 11                   FNR       rf_clf         0.013340     diabetes
# 12                   FPR       rf_clf         0.013340     diabetes
# 13                   PPV       rf_clf         0.013340     diabetes
# 14           Sample_Size       rf_clf         0.013340     diabetes
# 15        Selection-Rate       rf_clf         0.013340     diabetes
# 16                   TNR       rf_clf         0.013340     diabetes
# 17                   TPR       rf_clf         0.013340     diabetes
# 0               Accuracy  gandalf_clf         0.200396     diabetes
# 1                     F1  gandalf_clf         0.200396     diabetes
# 2                    FNR  gandalf_clf         0.200396     diabetes
# 3                    FPR  gandalf_clf         0.200396     diabetes
# 4                    PPV  gandalf_clf         0.200396     diabetes
# 5            Sample_Size  gandalf_clf         0.200396     diabetes
# 6         Selection-Rate  gandalf_clf         0.200396     diabetes
# 7                    TNR  gandalf_clf         0.200396     diabetes
# 8                    TPR  gandalf_clf         0.200396     diabetes
# 0               Accuracy  gandalf_clf         0.140299     diabetes
# 1                     F1  gandalf_clf         0.140299     diabetes
# 2                    FNR  gandalf_clf         0.140299     diabetes
# 3                    FPR  gandalf_clf         0.140299     diabetes
# 4                    PPV  gandalf_clf         0.140299     diabetes
# 5            Sample_Size  gandalf_clf         0.140299     diabetes
# 6         Selection-Rate  gandalf_clf         0.140299     diabetes
# 7                    TNR  gandalf_clf         0.140299     diabetes
# 8                    TPR  gandalf_clf         0.140299     diabetes
#
# subgroup                      logical_pipeline_name null_imputer_name  \
# 9              None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 10             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 11             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 12             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 13             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 14             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 15             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 16             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 17             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 0         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 1         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 2         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 3         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 4         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 5         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 6         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 7         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 8         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 0         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 1         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 2         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 3         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 4         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 5         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 6         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 7         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 8         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
#
# subgroup fairness_intervention_name  Gender_dis  Gender_priv     overall
# 9          NO_FAIRNESS_INTERVENTION    0.935185     0.865854    0.893382
# 10         NO_FAIRNESS_INTERVENTION    0.898551     0.760870    0.819876
# 11         NO_FAIRNESS_INTERVENTION    0.138889     0.326923    0.250000
# 12         NO_FAIRNESS_INTERVENTION    0.027778     0.044643    0.038043
# 13         NO_FAIRNESS_INTERVENTION    0.939394     0.875000    0.904110
# 14         NO_FAIRNESS_INTERVENTION  108.000000   164.000000  272.000000
# 15         NO_FAIRNESS_INTERVENTION    0.305556     0.243902    0.268382
# 16         NO_FAIRNESS_INTERVENTION    0.972222     0.955357    0.961957
# 17         NO_FAIRNESS_INTERVENTION    0.861111     0.673077    0.750000
# 0          NO_FAIRNESS_INTERVENTION    0.907407     0.890244    0.897059
# 1          NO_FAIRNESS_INTERVENTION    0.857143     0.812500    0.831325
# 2          NO_FAIRNESS_INTERVENTION    0.166667     0.250000    0.215909
# 3          NO_FAIRNESS_INTERVENTION    0.055556     0.044643    0.048913
# 4          NO_FAIRNESS_INTERVENTION    0.882353     0.886364    0.884615
# 5          NO_FAIRNESS_INTERVENTION  108.000000   164.000000  272.000000
# 6          NO_FAIRNESS_INTERVENTION    0.314815     0.268293    0.286765
# 7          NO_FAIRNESS_INTERVENTION    0.944444     0.955357    0.951087
# 8          NO_FAIRNESS_INTERVENTION    0.833333     0.750000    0.784091
# 0          NO_FAIRNESS_INTERVENTION    0.685185     0.670732    0.676471
# 1          NO_FAIRNESS_INTERVENTION    0.105263     0.000000    0.043478
# 2          NO_FAIRNESS_INTERVENTION    0.944444     1.000000    0.977273
# 3          NO_FAIRNESS_INTERVENTION    0.000000     0.017857    0.010870
# 4          NO_FAIRNESS_INTERVENTION    1.000000     0.000000    0.500000
# 5          NO_FAIRNESS_INTERVENTION  108.000000   164.000000  272.000000
# 6          NO_FAIRNESS_INTERVENTION    0.018519     0.012195    0.014706
# 7          NO_FAIRNESS_INTERVENTION    1.000000     0.982143    0.989130
# 8          NO_FAIRNESS_INTERVENTION    0.055556     0.000000    0.022727

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name='test_case_studies_exp',
                                           dataset_name='diabetes',
                                           case_study_name='cs1',
                                           metric_name="F1")
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Disparity metrics

# %%
create_box_plot_per_cost_model(to_plot=best_lp_metrics_per_exp_config_df, metric_name="Equalized_Odds_TPR", group=GROUP)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 create_box_plot_per_cost_model(to_plot=best_lp_metrics_per_exp_config_df, metric_name="Equalized_Odds_TPR", group=GROUP)
#
# File ~/Research/NYU/VirnyFlow_Project/Code/virny-flow-experiments/source/visualizations/cost_model_viz.py:39, in create_box_plot_per_cost_model(to_plot, metric_name, group, base_font_size, ylim)
#      31     y_column = 'disparity_metric_value'
#      33 # Create the box plot
#      34 box_plot = alt.Chart(filtered_df).mark_boxplot(
#      35     ticks=True,
#      36     median={'stroke': 'black', 'strokeWidth': 0.7},
#      37 ).encode(
#      38     x=alt.X('exp_config_name:N', title=None, axis=alt.Axis(labelAngle=-45, labelLimit=300)),
# ---> 39     y=alt.Y(f'{y_column}:Q', title=title, scale=alt.Scale(zero=False, domain=ylim)),
#      40 ).properties(
#      41     width=400,
#      42     height=400
#      43 )
#      45 final_chart = (
#      46     box_plot.configure_view(
#      47         stroke=None
#    (...)
#      55     )
#      56 )
#      58 return final_chart
#
# UnboundLocalError: local variable 'title' referenced before assignment
