# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings

warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "virny-flow-experiments":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/Research/NYU/VirnyFlow_Project/Code/virny-flow-experiments

# %% [markdown]
# # Case Studies Visualizations

# %%
from duckdb import query as sqldf
from source.visualizations.use_case_queries import get_best_lps_per_exp_config
from source.visualizations.cost_model_viz import create_box_plot_per_dataset_and_case_study

# %% [markdown]
# ## Prepare data for visualizations

# %%
SECRETS_PATH = os.path.join(os.getcwd(), "scripts", "configs", "secrets.env")
EXP_NAME = 'case_studies_exp'
DATASET_NAME = 'folk_emp'
GROUP = "SEX&RAC1P"
EXP_CONFIG_NAMES = [
    "case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fair_0_75",
    "case_studies_exp_folk_emp_cs1_w_acc_0_5_w_fair_0_5",
    "case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fair_0_25",
    "case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fair_0_75",
    "case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair_0_5",
    "case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fair_0_25",
    "case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fair1_0_25_w_fair2_0_5",
    # "case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fair1_0_5_w_fair2_0_25",
    "case_studies_exp_folk_emp_cs3_w_acc_0_33_w_fair1_0_33_w_fair2_0_33",
    "case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair1_0_25_w_fair2_0_25"
]

# %%
best_lp_metrics_per_exp_config_df = get_best_lps_per_exp_config(secrets_path=SECRETS_PATH, exp_config_names=EXP_CONFIG_NAMES)
# Out:
# Extracting metrics for case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fair_0_75...
# best_pps_per_lp_and_run_num_df.shape: (63, 19)
# max_lp_avg_compound_pp_quality: 0.937994826314771
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# Extracted metrics for case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fair_0_75
#
# Extracting metrics for case_studies_exp_folk_emp_cs1_w_acc_0_5_w_fair_0_5...
# best_pps_per_lp_and_run_num_df.shape: (63, 19)
# max_lp_avg_compound_pp_quality: 0.8915343387142372
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# Extracted metrics for case_studies_exp_folk_emp_cs1_w_acc_0_5_w_fair_0_5
#
# Extracting metrics for case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fair_0_25...
# best_pps_per_lp_and_run_num_df.shape: (63, 19)
# max_lp_avg_compound_pp_quality: 0.8502678798408856
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# Extracted metrics for case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fair_0_25
#
# Extracting metrics for case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fair_0_75...
# best_pps_per_lp_and_run_num_df.shape: (72, 19)
# max_lp_avg_compound_pp_quality: 0.927692774157758
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZGFsZl9jbGY=
# Extracted metrics for case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fair_0_75
#
# Extracting metrics for case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair_0_5...
# best_pps_per_lp_and_run_num_df.shape: (27, 19)
# max_lp_avg_compound_pp_quality: 0.8705651609532784
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV9jbGY=
# Extracted metrics for case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair_0_5
#
# Extracting metrics for case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fair_0_25...
# best_pps_per_lp_and_run_num_df.shape: (72, 19)
# max_lp_avg_compound_pp_quality: 0.836845251458207
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# Extracted metrics for case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fair_0_25
#
# Extracting metrics for case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fair1_0_25_w_fair2_0_5...
# best_pps_per_lp_and_run_num_df.shape: (72, 19)
# max_lp_avg_compound_pp_quality: 0.9283095758001122
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZGFsZl9jbGY=
# Extracted metrics for case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fair1_0_25_w_fair2_0_5
#
# Extracting metrics for case_studies_exp_folk_emp_cs3_w_acc_0_33_w_fair1_0_33_w_fair2_0_33...
# best_pps_per_lp_and_run_num_df.shape: (81, 19)
# max_lp_avg_compound_pp_quality: 0.9035530520438044
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZGFsZl9jbGY=
# Extracted metrics for case_studies_exp_folk_emp_cs3_w_acc_0_33_w_fair1_0_33_w_fair2_0_33
#
# Extracting metrics for case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair1_0_25_w_fair2_0_25...
# best_pps_per_lp_and_run_num_df.shape: (45, 19)
# max_lp_avg_compound_pp_quality: 0.8832848499252
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# Extracted metrics for case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair1_0_25_w_fair2_0_25

# %%
best_lp_metrics_per_exp_config_df.shape
# Out:
# (216, 19)

# %%
best_lp_metrics_per_exp_config_df.head()
# Out:
# subgroup                                    exp_config_name  \
# 27        case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...
# 28        case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...
# 29        case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...
# 30        case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...
# 31        case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...
#
# subgroup                             logical_pipeline_uuid  \
# 27        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 28        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 29        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 30        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 31        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
#
# subgroup                physical_pipeline_uuid  run_num  compound_pp_quality  \
# 27        157368a1-4389-4a58-9831-240493cdd6f2        3              0.93032
# 28        157368a1-4389-4a58-9831-240493cdd6f2        3              0.93032
# 29        157368a1-4389-4a58-9831-240493cdd6f2        3              0.93032
# 30        157368a1-4389-4a58-9831-240493cdd6f2        3              0.93032
# 31        157368a1-4389-4a58-9831-240493cdd6f2        3              0.93032
#
# subgroup    metric model_name  runtime_in_mins dataset_name  \
# 27        Accuracy     rf_clf         0.038101     folk_emp
# 28              F1     rf_clf         0.038101     folk_emp
# 29             FNR     rf_clf         0.038101     folk_emp
# 30             FPR     rf_clf         0.038101     folk_emp
# 31             PPV     rf_clf         0.038101     folk_emp
#
# subgroup                 logical_pipeline_name null_imputer_name  \
# 27        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 28        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 29        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 30        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 31        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
#
# subgroup fairness_intervention_name  RAC1P_dis  RAC1P_priv  SEX&RAC1P_dis  \
# 27         NO_FAIRNESS_INTERVENTION   0.768953    0.760042       0.713287
# 28         NO_FAIRNESS_INTERVENTION   0.815562    0.799470       0.763689
# 29         NO_FAIRNESS_INTERVENTION   0.104430    0.165129       0.119601
# 30         NO_FAIRNESS_INTERVENTION   0.399160    0.340347       0.472325
# 31         NO_FAIRNESS_INTERVENTION   0.748677    0.766949       0.674300
#
# subgroup  SEX&RAC1P_priv   SEX_dis  SEX_priv   overall
# 27              0.775124  0.731176  0.796097  0.763333
# 28              0.815416  0.770962  0.838400  0.805586
# 29              0.147703  0.136192  0.148429  0.142774
# 30              0.332675  0.414702  0.294849  0.362150
# 31              0.781594  0.696138  0.825630  0.759814

# %% [markdown]
# ## Get the best lp per exp config

# %%
# Get best lp per exp config
sqldf("""
    SELECT DISTINCT exp_config_name, logical_pipeline_name
    FROM best_lp_metrics_per_exp_config_df
""").to_df()
# Out:
#                                      exp_config_name  \
# 0  case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair...
# 1  case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...
# 2  case_studies_exp_folk_emp_cs1_w_acc_0_5_w_fair...
# 3  case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 4  case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fai...
# 5  case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fai...
# 6  case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 7  case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fai...
# 8  case_studies_exp_folk_emp_cs3_w_acc_0_33_w_fai...
#
#                        logical_pipeline_name
# 0       None&NO_FAIRNESS_INTERVENTION&rf_clf
# 1       None&NO_FAIRNESS_INTERVENTION&rf_clf
# 2       None&NO_FAIRNESS_INTERVENTION&rf_clf
# 3     None&NO_FAIRNESS_INTERVENTION&lgbm_clf
# 4       None&NO_FAIRNESS_INTERVENTION&rf_clf
# 5  None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 6       None&NO_FAIRNESS_INTERVENTION&rf_clf
# 7  None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 8  None&NO_FAIRNESS_INTERVENTION&gandalf_clf

# %% [markdown]
# ## Case study 1

# %%
CASE_STUDY_NAME = 'cs1'

# %%
to_plot = best_lp_metrics_per_exp_config_df
to_plot[(to_plot['dataset_name'] == DATASET_NAME) & (to_plot['exp_config_name'].str.contains(CASE_STUDY_NAME, case=False, na=False))]
# Out:
# subgroup                                    exp_config_name  \
# 27        case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...
# 28        case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...
# 29        case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...
# 30        case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...
# 31        case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...
# ..                                                      ...
# 58        case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fai...
# 59        case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fai...
# 60        case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fai...
# 61        case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fai...
# 62        case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fai...
#
# subgroup                             logical_pipeline_uuid  \
# 27        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 28        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 29        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 30        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 31        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# ..                                                     ...
# 58        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 59        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 60        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 61        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 62        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
#
# subgroup                physical_pipeline_uuid  run_num  compound_pp_quality  \
# 27        157368a1-4389-4a58-9831-240493cdd6f2        3             0.930320
# 28        157368a1-4389-4a58-9831-240493cdd6f2        3             0.930320
# 29        157368a1-4389-4a58-9831-240493cdd6f2        3             0.930320
# 30        157368a1-4389-4a58-9831-240493cdd6f2        3             0.930320
# 31        157368a1-4389-4a58-9831-240493cdd6f2        3             0.930320
# ..                                         ...      ...                  ...
# 58        d53524f0-4cb6-4831-82bd-d6e8e7c056be        2             0.855873
# 59        d53524f0-4cb6-4831-82bd-d6e8e7c056be        2             0.855873
# 60        d53524f0-4cb6-4831-82bd-d6e8e7c056be        2             0.855873
# 61        d53524f0-4cb6-4831-82bd-d6e8e7c056be        2             0.855873
# 62        d53524f0-4cb6-4831-82bd-d6e8e7c056be        2             0.855873
#
# subgroup          metric model_name  runtime_in_mins dataset_name  \
# 27              Accuracy     rf_clf         0.038101     folk_emp
# 28                    F1     rf_clf         0.038101     folk_emp
# 29                   FNR     rf_clf         0.038101     folk_emp
# 30                   FPR     rf_clf         0.038101     folk_emp
# 31                   PPV     rf_clf         0.038101     folk_emp
# ..                   ...        ...              ...          ...
# 58                   PPV     rf_clf         0.024646     folk_emp
# 59           Sample_Size     rf_clf         0.024646     folk_emp
# 60        Selection-Rate     rf_clf         0.024646     folk_emp
# 61                   TNR     rf_clf         0.024646     folk_emp
# 62                   TPR     rf_clf         0.024646     folk_emp
#
# subgroup                 logical_pipeline_name null_imputer_name  \
# 27        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 28        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 29        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 30        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 31        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# ..                                         ...               ...
# 58        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 59        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 60        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 61        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 62        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
#
# subgroup fairness_intervention_name    RAC1P_dis   RAC1P_priv  SEX&RAC1P_dis  \
# 27         NO_FAIRNESS_INTERVENTION     0.768953     0.760042       0.713287
# 28         NO_FAIRNESS_INTERVENTION     0.815562     0.799470       0.763689
# 29         NO_FAIRNESS_INTERVENTION     0.104430     0.165129       0.119601
# 30         NO_FAIRNESS_INTERVENTION     0.399160     0.340347       0.472325
# 31         NO_FAIRNESS_INTERVENTION     0.748677     0.766949       0.674300
# ..                              ...          ...          ...            ...
# 58         NO_FAIRNESS_INTERVENTION     0.746212     0.761702       0.688940
# 59         NO_FAIRNESS_INTERVENTION  1132.000000  1868.000000     604.000000
# 60         NO_FAIRNESS_INTERVENTION     0.699647     0.629015       0.718543
# 61         NO_FAIRNESS_INTERVENTION     0.575053     0.661017       0.488636
# 62         NO_FAIRNESS_INTERVENTION     0.896813     0.858925       0.879412
#
# subgroup  SEX&RAC1P_priv      SEX_dis     SEX_priv      overall
# 27              0.775124     0.731176     0.796097     0.763333
# 28              0.815416     0.770962     0.838400     0.805586
# 29              0.147703     0.136192     0.148429     0.142774
# 30              0.332675     0.414702     0.294849     0.362150
# 31              0.781594     0.696138     0.825630     0.759814
# ..                   ...          ...          ...          ...
# 58              0.774299     0.693878     0.823028     0.755465
# 59           2396.000000  1547.000000  1453.000000  3000.000000
# 60              0.639816     0.665158     0.645561     0.655667
# 61              0.665700     0.566116     0.710297     0.629715
# 62              0.872153     0.869671     0.877273     0.873604
#
# [99 rows x 19 columns]

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="F1")
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Equalized_Odds_FNR",
                                           group=GROUP)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Case study 2

# %%
CASE_STUDY_NAME = 'cs2'

# %%
to_plot = best_lp_metrics_per_exp_config_df
to_plot[(to_plot['dataset_name'] == DATASET_NAME) & (to_plot['exp_config_name'].str.contains(CASE_STUDY_NAME, case=False, na=False))]
# Out:
# subgroup                                    exp_config_name  \
# 0         case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fai...
# 1         case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fai...
# 2         case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fai...
# 3         case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fai...
# 4         case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fai...
# 5         case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fai...
# 6         case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fai...
# 7         case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fai...
# 8         case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fai...
# 0         case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 1         case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 2         case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 3         case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 4         case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 5         case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 6         case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 7         case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 8         case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 9         case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 10        case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 11        case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 12        case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 13        case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 14        case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 15        case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 16        case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 17        case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 18        case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 19        case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 20        case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 21        case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 22        case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 23        case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 24        case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 25        case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 26        case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 54        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 55        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 56        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 57        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 58        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 59        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 60        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 61        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 62        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 63        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 64        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 65        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 66        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 67        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 68        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 69        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 70        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 71        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
#
# subgroup                              logical_pipeline_uuid  \
# 0         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 1         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 2         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 3         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 4         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 5         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 6         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 7         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 8         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 0         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 1         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 2         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 3         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 4         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 5         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 6         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 7         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 8         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 9         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 10        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 11        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 12        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 13        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 14        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 15        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 16        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 17        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 18        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 19        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 20        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 21        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 22        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 23        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 24        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 25        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 26        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 54         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 55         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 56         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 57         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 58         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 59         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 60         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 61         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 62         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 63         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 64         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 65         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 66         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 67         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 68         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 69         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 70         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 71         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
#
# subgroup                physical_pipeline_uuid  run_num  compound_pp_quality  \
# 0         97b44aa6-dc64-4dc2-b722-8535c08651ed        3             0.927693
# 1         97b44aa6-dc64-4dc2-b722-8535c08651ed        3             0.927693
# 2         97b44aa6-dc64-4dc2-b722-8535c08651ed        3             0.927693
# 3         97b44aa6-dc64-4dc2-b722-8535c08651ed        3             0.927693
# 4         97b44aa6-dc64-4dc2-b722-8535c08651ed        3             0.927693
# 5         97b44aa6-dc64-4dc2-b722-8535c08651ed        3             0.927693
# 6         97b44aa6-dc64-4dc2-b722-8535c08651ed        3             0.927693
# 7         97b44aa6-dc64-4dc2-b722-8535c08651ed        3             0.927693
# 8         97b44aa6-dc64-4dc2-b722-8535c08651ed        3             0.927693
# 0         2d097d63-cc15-4d70-88d1-abdd4d78d9ca        1             0.870587
# 1         2d097d63-cc15-4d70-88d1-abdd4d78d9ca        1             0.870587
# 2         2d097d63-cc15-4d70-88d1-abdd4d78d9ca        1             0.870587
# 3         2d097d63-cc15-4d70-88d1-abdd4d78d9ca        1             0.870587
# 4         2d097d63-cc15-4d70-88d1-abdd4d78d9ca        1             0.870587
# 5         2d097d63-cc15-4d70-88d1-abdd4d78d9ca        1             0.870587
# 6         2d097d63-cc15-4d70-88d1-abdd4d78d9ca        1             0.870587
# 7         2d097d63-cc15-4d70-88d1-abdd4d78d9ca        1             0.870587
# 8         2d097d63-cc15-4d70-88d1-abdd4d78d9ca        1             0.870587
# 9         846f918a-bd18-4953-88bf-a20d4c306818        2             0.867803
# 10        846f918a-bd18-4953-88bf-a20d4c306818        2             0.867803
# 11        846f918a-bd18-4953-88bf-a20d4c306818        2             0.867803
# 12        846f918a-bd18-4953-88bf-a20d4c306818        2             0.867803
# 13        846f918a-bd18-4953-88bf-a20d4c306818        2             0.867803
# 14        846f918a-bd18-4953-88bf-a20d4c306818        2             0.867803
# 15        846f918a-bd18-4953-88bf-a20d4c306818        2             0.867803
# 16        846f918a-bd18-4953-88bf-a20d4c306818        2             0.867803
# 17        846f918a-bd18-4953-88bf-a20d4c306818        2             0.867803
# 18        8ea591d3-56df-4801-bd9a-1bb4cb134bb4        5             0.873305
# 19        8ea591d3-56df-4801-bd9a-1bb4cb134bb4        5             0.873305
# 20        8ea591d3-56df-4801-bd9a-1bb4cb134bb4        5             0.873305
# 21        8ea591d3-56df-4801-bd9a-1bb4cb134bb4        5             0.873305
# 22        8ea591d3-56df-4801-bd9a-1bb4cb134bb4        5             0.873305
# 23        8ea591d3-56df-4801-bd9a-1bb4cb134bb4        5             0.873305
# 24        8ea591d3-56df-4801-bd9a-1bb4cb134bb4        5             0.873305
# 25        8ea591d3-56df-4801-bd9a-1bb4cb134bb4        5             0.873305
# 26        8ea591d3-56df-4801-bd9a-1bb4cb134bb4        5             0.873305
# 54        331a2f1a-1049-4f70-8fb6-a8102fcc79c5        2             0.838006
# 55        331a2f1a-1049-4f70-8fb6-a8102fcc79c5        2             0.838006
# 56        331a2f1a-1049-4f70-8fb6-a8102fcc79c5        2             0.838006
# 57        331a2f1a-1049-4f70-8fb6-a8102fcc79c5        2             0.838006
# 58        331a2f1a-1049-4f70-8fb6-a8102fcc79c5        2             0.838006
# 59        331a2f1a-1049-4f70-8fb6-a8102fcc79c5        2             0.838006
# 60        331a2f1a-1049-4f70-8fb6-a8102fcc79c5        2             0.838006
# 61        331a2f1a-1049-4f70-8fb6-a8102fcc79c5        2             0.838006
# 62        331a2f1a-1049-4f70-8fb6-a8102fcc79c5        2             0.838006
# 63        589e59c1-8398-4003-8955-a8396b524728        4             0.835684
# 64        589e59c1-8398-4003-8955-a8396b524728        4             0.835684
# 65        589e59c1-8398-4003-8955-a8396b524728        4             0.835684
# 66        589e59c1-8398-4003-8955-a8396b524728        4             0.835684
# 67        589e59c1-8398-4003-8955-a8396b524728        4             0.835684
# 68        589e59c1-8398-4003-8955-a8396b524728        4             0.835684
# 69        589e59c1-8398-4003-8955-a8396b524728        4             0.835684
# 70        589e59c1-8398-4003-8955-a8396b524728        4             0.835684
# 71        589e59c1-8398-4003-8955-a8396b524728        4             0.835684
#
# subgroup          metric   model_name  runtime_in_mins dataset_name  \
# 0               Accuracy  gandalf_clf         2.183085     folk_emp
# 1                     F1  gandalf_clf         2.183085     folk_emp
# 2                    FNR  gandalf_clf         2.183085     folk_emp
# 3                    FPR  gandalf_clf         2.183085     folk_emp
# 4                    PPV  gandalf_clf         2.183085     folk_emp
# 5            Sample_Size  gandalf_clf         2.183085     folk_emp
# 6         Selection-Rate  gandalf_clf         2.183085     folk_emp
# 7                    TNR  gandalf_clf         2.183085     folk_emp
# 8                    TPR  gandalf_clf         2.183085     folk_emp
# 0               Accuracy     lgbm_clf         0.007136     folk_emp
# 1                     F1     lgbm_clf         0.007136     folk_emp
# 2                    FNR     lgbm_clf         0.007136     folk_emp
# 3                    FPR     lgbm_clf         0.007136     folk_emp
# 4                    PPV     lgbm_clf         0.007136     folk_emp
# 5            Sample_Size     lgbm_clf         0.007136     folk_emp
# 6         Selection-Rate     lgbm_clf         0.007136     folk_emp
# 7                    TNR     lgbm_clf         0.007136     folk_emp
# 8                    TPR     lgbm_clf         0.007136     folk_emp
# 9               Accuracy     lgbm_clf         0.010127     folk_emp
# 10                    F1     lgbm_clf         0.010127     folk_emp
# 11                   FNR     lgbm_clf         0.010127     folk_emp
# 12                   FPR     lgbm_clf         0.010127     folk_emp
# 13                   PPV     lgbm_clf         0.010127     folk_emp
# 14           Sample_Size     lgbm_clf         0.010127     folk_emp
# 15        Selection-Rate     lgbm_clf         0.010127     folk_emp
# 16                   TNR     lgbm_clf         0.010127     folk_emp
# 17                   TPR     lgbm_clf         0.010127     folk_emp
# 18              Accuracy     lgbm_clf         0.006931     folk_emp
# 19                    F1     lgbm_clf         0.006931     folk_emp
# 20                   FNR     lgbm_clf         0.006931     folk_emp
# 21                   FPR     lgbm_clf         0.006931     folk_emp
# 22                   PPV     lgbm_clf         0.006931     folk_emp
# 23           Sample_Size     lgbm_clf         0.006931     folk_emp
# 24        Selection-Rate     lgbm_clf         0.006931     folk_emp
# 25                   TNR     lgbm_clf         0.006931     folk_emp
# 26                   TPR     lgbm_clf         0.006931     folk_emp
# 54              Accuracy       rf_clf         0.024595     folk_emp
# 55                    F1       rf_clf         0.024595     folk_emp
# 56                   FNR       rf_clf         0.024595     folk_emp
# 57                   FPR       rf_clf         0.024595     folk_emp
# 58                   PPV       rf_clf         0.024595     folk_emp
# 59           Sample_Size       rf_clf         0.024595     folk_emp
# 60        Selection-Rate       rf_clf         0.024595     folk_emp
# 61                   TNR       rf_clf         0.024595     folk_emp
# 62                   TPR       rf_clf         0.024595     folk_emp
# 63              Accuracy       rf_clf         0.059112     folk_emp
# 64                    F1       rf_clf         0.059112     folk_emp
# 65                   FNR       rf_clf         0.059112     folk_emp
# 66                   FPR       rf_clf         0.059112     folk_emp
# 67                   PPV       rf_clf         0.059112     folk_emp
# 68           Sample_Size       rf_clf         0.059112     folk_emp
# 69        Selection-Rate       rf_clf         0.059112     folk_emp
# 70                   TNR       rf_clf         0.059112     folk_emp
# 71                   TPR       rf_clf         0.059112     folk_emp
#
# subgroup                      logical_pipeline_name null_imputer_name  \
# 0         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 1         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 2         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 3         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 4         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 5         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 6         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 7         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 8         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 0            None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 1            None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 2            None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 3            None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 4            None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 5            None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 6            None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 7            None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 8            None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 9            None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 10           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 11           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 12           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 13           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 14           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 15           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 16           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 17           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 18           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 19           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 20           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 21           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 22           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 23           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 24           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 25           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 26           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 54             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 55             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 56             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 57             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 58             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 59             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 60             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 61             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 62             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 63             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 64             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 65             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 66             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 67             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 68             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 69             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 70             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 71             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
#
# subgroup fairness_intervention_name    RAC1P_dis   RAC1P_priv  SEX&RAC1P_dis  \
# 0          NO_FAIRNESS_INTERVENTION     0.647112     0.637949       0.597902
# 1          NO_FAIRNESS_INTERVENTION     0.762310     0.755967       0.722892
# 2          NO_FAIRNESS_INTERVENTION     0.007911     0.021218       0.003322
# 3          NO_FAIRNESS_INTERVENTION     0.810924     0.819307       0.845018
# 4          NO_FAIRNESS_INTERVENTION     0.618954     0.615786       0.567108
# 5          NO_FAIRNESS_INTERVENTION  1108.000000  1892.000000     572.000000
# 6          NO_FAIRNESS_INTERVENTION     0.914260     0.910677       0.924825
# 7          NO_FAIRNESS_INTERVENTION     0.189076     0.180693       0.154982
# 8          NO_FAIRNESS_INTERVENTION     0.992089     0.978782       0.996678
# 0          NO_FAIRNESS_INTERVENTION     0.738616     0.757624       0.715054
# 1          NO_FAIRNESS_INTERVENTION     0.800000     0.802739       0.775740
# 2          NO_FAIRNESS_INTERVENTION     0.105919     0.143379       0.092409
# 3          NO_FAIRNESS_INTERVENTION     0.480263     0.376704       0.513725
# 4          NO_FAIRNESS_INTERVENTION     0.723834     0.755233       0.677340
# 5          NO_FAIRNESS_INTERVENTION  1098.000000  1902.000000     558.000000
# 6          NO_FAIRNESS_INTERVENTION     0.722222     0.652997       0.727599
# 7          NO_FAIRNESS_INTERVENTION     0.519737     0.623296       0.486275
# 8          NO_FAIRNESS_INTERVENTION     0.894081     0.856621       0.907591
# 9          NO_FAIRNESS_INTERVENTION     0.747350     0.763919       0.715232
# 10         NO_FAIRNESS_INTERVENTION     0.803301     0.801619       0.776623
# 11         NO_FAIRNESS_INTERVENTION     0.113809     0.144914       0.120588
# 12         NO_FAIRNESS_INTERVENTION     0.446089     0.351090       0.496212
# 13         NO_FAIRNESS_INTERVENTION     0.734591     0.754445       0.695349
# 14         NO_FAIRNESS_INTERVENTION  1132.000000  1868.000000     604.000000
# 15         NO_FAIRNESS_INTERVENTION     0.702297     0.632227       0.711921
# 16         NO_FAIRNESS_INTERVENTION     0.553911     0.648910       0.503788
# 17         NO_FAIRNESS_INTERVENTION     0.886191     0.855086       0.879412
# 18         NO_FAIRNESS_INTERVENTION     0.750663     0.740503       0.702936
# 19         NO_FAIRNESS_INTERVENTION     0.806052     0.778032       0.756374
# 20         NO_FAIRNESS_INTERVENTION     0.095679     0.176357       0.133117
# 21         NO_FAIRNESS_INTERVENTION     0.455487     0.362007       0.483395
# 22         NO_FAIRNESS_INTERVENTION     0.727047     0.737207       0.670854
# 23         NO_FAIRNESS_INTERVENTION  1131.000000  1869.000000     579.000000
# 24         NO_FAIRNESS_INTERVENTION     0.712644     0.616907       0.687392
# 25         NO_FAIRNESS_INTERVENTION     0.544513     0.637993       0.516605
# 26         NO_FAIRNESS_INTERVENTION     0.904321     0.823643       0.866883
# 54         NO_FAIRNESS_INTERVENTION     0.762367     0.771413       0.708609
# 55         NO_FAIRNESS_INTERVENTION     0.814611     0.807397       0.772610
# 56         NO_FAIRNESS_INTERVENTION     0.103187     0.141075       0.120588
# 57         NO_FAIRNESS_INTERVENTION     0.424947     0.338983       0.511364
# 58         NO_FAIRNESS_INTERVENTION     0.746212     0.761702       0.688940
# 59         NO_FAIRNESS_INTERVENTION  1132.000000  1868.000000     604.000000
# 60         NO_FAIRNESS_INTERVENTION     0.699647     0.629015       0.718543
# 61         NO_FAIRNESS_INTERVENTION     0.575053     0.661017       0.488636
# 62         NO_FAIRNESS_INTERVENTION     0.896813     0.858925       0.879412
# 63         NO_FAIRNESS_INTERVENTION     0.750675     0.766014       0.708621
# 64         NO_FAIRNESS_INTERVENTION     0.806969     0.805800       0.773154
# 65         NO_FAIRNESS_INTERVENTION     0.086751     0.119962       0.088608
# 66         NO_FAIRNESS_INTERVENTION     0.465409     0.374262       0.534091
# 67         NO_FAIRNESS_INTERVENTION     0.722846     0.743112       0.671329
# 68         NO_FAIRNESS_INTERVENTION  1111.000000  1889.000000     580.000000
# 69         NO_FAIRNESS_INTERVENTION     0.720972     0.653256       0.739655
# 70         NO_FAIRNESS_INTERVENTION     0.534591     0.625738       0.465909
# 71         NO_FAIRNESS_INTERVENTION     0.913249     0.880038       0.911392
#
# subgroup  SEX&RAC1P_priv      SEX_dis     SEX_priv      overall
# 0               0.651565     0.587186     0.696501     0.641333
# 1               0.766427     0.715262     0.800177     0.758311
# 2               0.019081     0.010088     0.021668     0.016317
# 3               0.808490     0.855756     0.765542     0.816199
# 4               0.628908     0.559914     0.676912     0.616959
# 5            2428.000000  1514.000000  1486.000000  3000.000000
# 6               0.908979     0.926024     0.897712     0.912000
# 7               0.191510     0.144244     0.234458     0.183801
# 8               0.980919     0.989912     0.978332     0.983683
# 0               0.758804     0.730360     0.771028     0.750667
# 1               0.807705     0.773109     0.827378     0.801697
# 2               0.137378     0.117647     0.139267     0.129534
# 3               0.388889     0.434722     0.386740     0.414093
# 4               0.759362     0.687936     0.796512     0.742998
# 5            2442.000000  1502.000000  1498.000000  3000.000000
# 6               0.667076     0.667776     0.688919     0.678333
# 7               0.611111     0.565278     0.613260     0.585907
# 8               0.862622     0.882353     0.860733     0.870466
# 9               0.768364     0.727214     0.790089     0.757667
# 10              0.809082     0.771150     0.833606     0.802284
# 11              0.135929     0.133983     0.131818     0.132863
# 12              0.357488     0.429752     0.329843     0.385681
# 13              0.760673     0.695015     0.801679     0.746457
# 14           2396.000000  1547.000000  1453.000000  3000.000000
# 15              0.645242     0.661280     0.655884     0.658667
# 16              0.642512     0.570248     0.670157     0.614319
# 17              0.864071     0.866017     0.868182     0.867137
# 18              0.754234     0.706117     0.782754     0.744333
# 19              0.797136     0.744804     0.829575     0.789228
# 20              0.147959     0.160156     0.132675     0.145238
# 21              0.373689     0.433424     0.349315     0.396212
# 22              0.748879     0.669087     0.794975     0.733027
# 23           2421.000000  1504.000000  1496.000000  3000.000000
# 24              0.644775     0.640957     0.665107     0.653000
# 25              0.626311     0.566576     0.650685     0.603788
# 26              0.852041     0.839844     0.867325     0.854762
# 54              0.782972     0.727214     0.811425     0.768000
# 55              0.820318     0.771892     0.849285     0.810251
# 56              0.127847     0.130329     0.122727     0.126396
# 57              0.334300     0.433884     0.289703     0.370285
# 58              0.774299     0.693878     0.823028     0.755465
# 59           2396.000000  1547.000000  1453.000000  3000.000000
# 60              0.639816     0.665158     0.645561     0.655667
# 61              0.665700     0.566116     0.710297     0.629715
# 62              0.872153     0.869671     0.877273     0.873604
# 63              0.772727     0.734405     0.788235     0.760333
# 64              0.814565     0.778790     0.834056     0.806252
# 65              0.111765     0.104680     0.109954     0.107399
# 66              0.375472     0.441454     0.363167     0.407100
# 67              0.752179     0.689100     0.784694     0.735135
# 68           2420.000000  1555.000000  1445.000000  3000.000000
# 69              0.663636     0.678457     0.678201     0.678333
# 70              0.624528     0.558546     0.636833     0.592900
# 71              0.888235     0.895320     0.890046     0.892601

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="F1")
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Selection_Rate_Difference",
                                           group=GROUP)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Case study 3

# %%
CASE_STUDY_NAME = 'cs3'

# %%
to_plot = best_lp_metrics_per_exp_config_df
to_plot[(to_plot['dataset_name'] == DATASET_NAME) & (to_plot['exp_config_name'].str.contains(CASE_STUDY_NAME, case=False, na=False))]
# Out:
# subgroup                                    exp_config_name  \
# 0         case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fai...
# 1         case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fai...
# 2         case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fai...
# 3         case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fai...
# 4         case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fai...
# ..                                                      ...
# 40        case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair...
# 41        case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair...
# 42        case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair...
# 43        case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair...
# 44        case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair...
#
# subgroup                              logical_pipeline_uuid  \
# 0         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 1         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 2         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 3         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 4         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# ..                                                      ...
# 40         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 41         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 42         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 43         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 44         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
#
# subgroup                physical_pipeline_uuid  run_num  compound_pp_quality  \
# 0         071426d2-7e51-48e9-bfda-470f3785d9dd        2             0.923680
# 1         071426d2-7e51-48e9-bfda-470f3785d9dd        2             0.923680
# 2         071426d2-7e51-48e9-bfda-470f3785d9dd        2             0.923680
# 3         071426d2-7e51-48e9-bfda-470f3785d9dd        2             0.923680
# 4         071426d2-7e51-48e9-bfda-470f3785d9dd        2             0.923680
# ..                                         ...      ...                  ...
# 40        a9cef381-3f4c-4e28-8b1c-ab80fca9fef4        3             0.882877
# 41        a9cef381-3f4c-4e28-8b1c-ab80fca9fef4        3             0.882877
# 42        a9cef381-3f4c-4e28-8b1c-ab80fca9fef4        3             0.882877
# 43        a9cef381-3f4c-4e28-8b1c-ab80fca9fef4        3             0.882877
# 44        a9cef381-3f4c-4e28-8b1c-ab80fca9fef4        3             0.882877
#
# subgroup          metric   model_name  runtime_in_mins dataset_name  \
# 0               Accuracy  gandalf_clf         1.465572     folk_emp
# 1                     F1  gandalf_clf         1.465572     folk_emp
# 2                    FNR  gandalf_clf         1.465572     folk_emp
# 3                    FPR  gandalf_clf         1.465572     folk_emp
# 4                    PPV  gandalf_clf         1.465572     folk_emp
# ..                   ...          ...              ...          ...
# 40                   PPV       rf_clf         0.035788     folk_emp
# 41           Sample_Size       rf_clf         0.035788     folk_emp
# 42        Selection-Rate       rf_clf         0.035788     folk_emp
# 43                   TNR       rf_clf         0.035788     folk_emp
# 44                   TPR       rf_clf         0.035788     folk_emp
#
# subgroup                      logical_pipeline_name null_imputer_name  \
# 0         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 1         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 2         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 3         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 4         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# ..                                              ...               ...
# 40             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 41             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 42             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 43             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 44             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
#
# subgroup fairness_intervention_name    RAC1P_dis   RAC1P_priv  SEX&RAC1P_dis  \
# 0          NO_FAIRNESS_INTERVENTION     0.730565     0.729657       0.693709
# 1          NO_FAIRNESS_INTERVENTION     0.792093     0.776648       0.759428
# 2          NO_FAIRNESS_INTERVENTION     0.118361     0.157390       0.141176
# 3          NO_FAIRNESS_INTERVENTION     0.479915     0.412833       0.518939
# 4          NO_FAIRNESS_INTERVENTION     0.719059     0.720263       0.680653
# ..                              ...          ...          ...            ...
# 40         NO_FAIRNESS_INTERVENTION     0.748677     0.766949       0.674300
# 41         NO_FAIRNESS_INTERVENTION  1108.000000  1892.000000     572.000000
# 42         NO_FAIRNESS_INTERVENTION     0.682310     0.623679       0.687063
# 43         NO_FAIRNESS_INTERVENTION     0.600840     0.659653       0.527675
# 44         NO_FAIRNESS_INTERVENTION     0.895570     0.834871       0.880399
#
# subgroup  SEX&RAC1P_priv      SEX_dis     SEX_priv      overall
# 0               0.739149     0.695540     0.766690     0.730000
# 1               0.788780     0.747994     0.817644     0.782725
# 2               0.142542     0.148599     0.136364     0.142269
# 3               0.416425     0.480716     0.382199     0.437259
# 4               0.730288     0.666985     0.776302     0.719783
# ..                   ...          ...          ...          ...
# 40              0.781594     0.696138     0.825630     0.759814
# 41           2428.000000  1514.000000  1486.000000  3000.000000
# 42              0.635502     0.649934     0.640646     0.645333
# 43              0.667325     0.585298     0.705151     0.637850
# 44              0.852297     0.863808     0.851571     0.857226
#
# [63 rows x 19 columns]

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="F1")
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Equalized_Odds_FNR",
                                           group=GROUP)
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Selection_Rate_Difference",
                                           group=GROUP)
# Out:
# alt.Chart(...)
