# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import warnings

warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "virny-flow-experiments":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/Research/NYU/VirnyFlow_Project/Code/virny-flow-experiments

# %% [markdown]
# # Case Studies Visualizations

# %%
from duckdb import query as sqldf
from source.visualizations.use_case_queries import get_best_lps_per_exp_config
from source.visualizations.cost_model_viz import create_box_plot_per_dataset_and_case_study

# %% [markdown]
# ## Prepare data for visualizations

# %%
SECRETS_PATH = os.path.join(os.getcwd(), "scripts", "configs", "secrets.env")
EXP_NAME = 'case_studies_exp'
DATASET_NAME = 'folk_emp'
GROUP = "SEX&RAC1P"
EXP_CONFIG_NAMES = [
    "case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fair_0_75",
    "case_studies_exp_folk_emp_cs1_w_acc_0_5_w_fair_0_5",
    "case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fair_0_25",
    "case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fair_0_75",
    "case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair_0_5",
    "case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fair_0_25",
    "case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fair1_0_25_w_fair2_0_5",
    "case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fair1_0_5_w_fair2_0_25",
    "case_studies_exp_folk_emp_cs3_w_acc_0_33_w_fair1_0_33_w_fair2_0_33",
    "case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair1_0_25_w_fair2_0_25"
]

# %%
best_lp_metrics_per_exp_config_df = get_best_lps_per_exp_config(secrets_path=SECRETS_PATH, exp_config_names=EXP_CONFIG_NAMES)
# Out:
# Extracting metrics for case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fair_0_75...
# best_pps_per_lp_and_run_num_df.shape: (63, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fair_0_75
#
# Extracting metrics for case_studies_exp_folk_emp_cs1_w_acc_0_5_w_fair_0_5...
# best_pps_per_lp_and_run_num_df.shape: (81, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_emp_cs1_w_acc_0_5_w_fair_0_5
#
# Extracting metrics for case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fair_0_25...
# best_pps_per_lp_and_run_num_df.shape: (54, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fair_0_25
#
# Extracting metrics for case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fair_0_75...
# best_pps_per_lp_and_run_num_df.shape: (54, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fair_0_75
#
# Extracting metrics for case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair_0_5...
# best_pps_per_lp_and_run_num_df.shape: (63, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair_0_5
#
# Extracting metrics for case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fair_0_25...
# best_pps_per_lp_and_run_num_df.shape: (63, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fair_0_25
#
# Extracting metrics for case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fair1_0_25_w_fair2_0_5...
# best_pps_per_lp_and_run_num_df.shape: (72, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fair1_0_25_w_fair2_0_5
#
# Extracting metrics for case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fair1_0_5_w_fair2_0_25...
# best_pps_per_lp_and_run_num_df.shape: (81, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fair1_0_5_w_fair2_0_25
#
# Extracting metrics for case_studies_exp_folk_emp_cs3_w_acc_0_33_w_fair1_0_33_w_fair2_0_33...
# best_pps_per_lp_and_run_num_df.shape: (54, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_emp_cs3_w_acc_0_33_w_fair1_0_33_w_fair2_0_33
#
# Extracting metrics for case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair1_0_25_w_fair2_0_25...
# best_pps_per_lp_and_run_num_df.shape: (63, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair1_0_25_w_fair2_0_25

# %%
best_lp_metrics_per_exp_config_df.shape
# Out:
# (450, 19)

# %%
best_lp_metrics_per_exp_config_df.head()
# Out:
# subgroup                                    exp_config_name  run_num  \
# 0         case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...        1
# 1         case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...        1
# 2         case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...        1
# 3         case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...        1
# 4         case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...        1
#
# subgroup                              logical_pipeline_uuid  \
# 0         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 1         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 2         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 3         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 4         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
#
# subgroup                physical_pipeline_uuid  compound_pp_quality    metric  \
# 0         c08cd634-002a-4c19-af64-1cca59d0bbcf             0.945997  Accuracy
# 1         c08cd634-002a-4c19-af64-1cca59d0bbcf             0.945997        F1
# 2         c08cd634-002a-4c19-af64-1cca59d0bbcf             0.945997       FNR
# 3         c08cd634-002a-4c19-af64-1cca59d0bbcf             0.945997       FPR
# 4         c08cd634-002a-4c19-af64-1cca59d0bbcf             0.945997       PPV
#
# subgroup   model_name  runtime_in_mins dataset_name  \
# 0         gandalf_clf         3.547661     folk_emp
# 1         gandalf_clf         3.547661     folk_emp
# 2         gandalf_clf         3.547661     folk_emp
# 3         gandalf_clf         3.547661     folk_emp
# 4         gandalf_clf         3.547661     folk_emp
#
# subgroup                      logical_pipeline_name null_imputer_name  \
# 0         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 1         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 2         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 3         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 4         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
#
# subgroup fairness_intervention_name  RAC1P_dis  RAC1P_priv  SEX&RAC1P_dis  \
# 0          NO_FAIRNESS_INTERVENTION   0.729508    0.741325       0.700717
# 1          NO_FAIRNESS_INTERVENTION   0.788009    0.790816       0.756204
# 2          NO_FAIRNESS_INTERVENTION   0.140187    0.150685       0.145215
# 3          NO_FAIRNESS_INTERVENTION   0.453947    0.405204       0.482353
# 4          NO_FAIRNESS_INTERVENTION   0.727273    0.739857       0.678010
#
# subgroup  SEX&RAC1P_priv   SEX_dis  SEX_priv   overall
# 0               0.745291  0.706391  0.767690  0.737000
# 1               0.797262  0.750707  0.824597  0.789768
# 2               0.147141  0.150895  0.143455  0.146805
# 3               0.407738  0.448611  0.388582  0.422803
# 4               0.748470  0.672746  0.794947  0.735119

# %% [markdown]
# ## Get the best lp per exp config

# %%
# Get best lp per exp config
sqldf("""
    SELECT DISTINCT exp_config_name, logical_pipeline_name
    FROM best_lp_metrics_per_exp_config_df
""").to_df()
# Out:
#                                       exp_config_name  \
# 0   case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...
# 1   case_studies_exp_folk_emp_cs1_w_acc_0_5_w_fair...
# 2   case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fai...
# 3   case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 4   case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fai...
# 5   case_studies_exp_folk_emp_cs3_w_acc_0_33_w_fai...
# 6   case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fai...
# 7   case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fai...
# 8   case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 9   case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair...
# 10  case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fai...
# 11  case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...
# 12  case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...
# 13  case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 14  case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair...
# 15  case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...
# 16  case_studies_exp_folk_emp_cs1_w_acc_0_5_w_fair...
# 17  case_studies_exp_folk_emp_cs2_w_acc_0_5_w_fair...
# 18  case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair...
#
#                         logical_pipeline_name
# 0        None&NO_FAIRNESS_INTERVENTION&rf_clf
# 1   None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 2   None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 3      None&NO_FAIRNESS_INTERVENTION&lgbm_clf
# 4   None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 5   None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 6        None&NO_FAIRNESS_INTERVENTION&rf_clf
# 7   None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 8        None&NO_FAIRNESS_INTERVENTION&rf_clf
# 9        None&NO_FAIRNESS_INTERVENTION&rf_clf
# 10  None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 11  None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 12     None&NO_FAIRNESS_INTERVENTION&lgbm_clf
# 13  None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 14  None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 15  None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 16       None&NO_FAIRNESS_INTERVENTION&rf_clf
# 17     None&NO_FAIRNESS_INTERVENTION&lgbm_clf
# 18     None&NO_FAIRNESS_INTERVENTION&lgbm_clf

# %% [markdown]
# ## Case study 1

# %%
CASE_STUDY_NAME = 'cs1'

# %%
to_plot = best_lp_metrics_per_exp_config_df
to_plot[(to_plot['dataset_name'] == DATASET_NAME) & (to_plot['exp_config_name'].str.contains(CASE_STUDY_NAME, case=False, na=False))]
# Out:
# subgroup                                    exp_config_name  run_num  \
# 0         case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...        1
# 1         case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...        1
# 2         case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...        1
# 3         case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...        1
# 4         case_studies_exp_folk_emp_cs1_w_acc_0_25_w_fai...        1
# ..                                                      ...      ...
# 49        case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fai...        5
# 50        case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fai...        5
# 51        case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fai...        5
# 52        case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fai...        5
# 53        case_studies_exp_folk_emp_cs1_w_acc_0_75_w_fai...        5
#
# subgroup                              logical_pipeline_uuid  \
# 0         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 1         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 2         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 3         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 4         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# ..                                                      ...
# 49        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 50        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 51        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 52        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 53        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
#
# subgroup                physical_pipeline_uuid  compound_pp_quality  \
# 0         c08cd634-002a-4c19-af64-1cca59d0bbcf             0.945997
# 1         c08cd634-002a-4c19-af64-1cca59d0bbcf             0.945997
# 2         c08cd634-002a-4c19-af64-1cca59d0bbcf             0.945997
# 3         c08cd634-002a-4c19-af64-1cca59d0bbcf             0.945997
# 4         c08cd634-002a-4c19-af64-1cca59d0bbcf             0.945997
# ..                                         ...                  ...
# 49        ff02eeb6-1707-4808-83fa-8e55d0d38ad4             0.851379
# 50        ff02eeb6-1707-4808-83fa-8e55d0d38ad4             0.851379
# 51        ff02eeb6-1707-4808-83fa-8e55d0d38ad4             0.851379
# 52        ff02eeb6-1707-4808-83fa-8e55d0d38ad4             0.851379
# 53        ff02eeb6-1707-4808-83fa-8e55d0d38ad4             0.851379
#
# subgroup          metric   model_name  runtime_in_mins dataset_name  \
# 0               Accuracy  gandalf_clf         3.547661     folk_emp
# 1                     F1  gandalf_clf         3.547661     folk_emp
# 2                    FNR  gandalf_clf         3.547661     folk_emp
# 3                    FPR  gandalf_clf         3.547661     folk_emp
# 4                    PPV  gandalf_clf         3.547661     folk_emp
# ..                   ...          ...              ...          ...
# 49                   PPV  gandalf_clf         2.974573     folk_emp
# 50           Sample_Size  gandalf_clf         2.974573     folk_emp
# 51        Selection-Rate  gandalf_clf         2.974573     folk_emp
# 52                   TNR  gandalf_clf         2.974573     folk_emp
# 53                   TPR  gandalf_clf         2.974573     folk_emp
#
# subgroup                      logical_pipeline_name null_imputer_name  \
# 0         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 1         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 2         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 3         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 4         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# ..                                              ...               ...
# 49        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 50        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 51        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 52        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 53        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
#
# subgroup fairness_intervention_name    RAC1P_dis   RAC1P_priv  SEX&RAC1P_dis  \
# 0          NO_FAIRNESS_INTERVENTION     0.729508     0.741325       0.700717
# 1          NO_FAIRNESS_INTERVENTION     0.788009     0.790816       0.756204
# 2          NO_FAIRNESS_INTERVENTION     0.140187     0.150685       0.145215
# 3          NO_FAIRNESS_INTERVENTION     0.453947     0.405204       0.482353
# 4          NO_FAIRNESS_INTERVENTION     0.727273     0.739857       0.678010
# ..                              ...          ...          ...            ...
# 49         NO_FAIRNESS_INTERVENTION     0.721176     0.725896       0.666667
# 50         NO_FAIRNESS_INTERVENTION  1131.000000  1869.000000     579.000000
# 51         NO_FAIRNESS_INTERVENTION     0.751547     0.671482       0.730570
# 52         NO_FAIRNESS_INTERVENTION     0.509317     0.589008       0.479705
# 53         NO_FAIRNESS_INTERVENTION     0.945988     0.882752       0.915584
#
# subgroup  SEX&RAC1P_priv      SEX_dis     SEX_priv      overall
# 0               0.745291     0.706391     0.767690     0.737000
# 1               0.797262     0.750707     0.824597     0.789768
# 2               0.147141     0.150895     0.143455     0.146805
# 3               0.407738     0.448611     0.388582     0.422803
# 4               0.748470     0.672746     0.794947     0.735119
# ..                   ...          ...          ...          ...
# 49              0.738407     0.656788     0.790368     0.723990
# 50           2421.000000  1504.000000  1496.000000  3000.000000
# 51              0.694754     0.695479     0.707888     0.701667
# 52              0.580553     0.512228     0.619863     0.559848
# 53              0.905248     0.894531     0.917763     0.907143
#
# [135 rows x 19 columns]

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="F1")
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Equalized_Odds_FNR",
                                           group=GROUP)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Case study 2

# %%
CASE_STUDY_NAME = 'cs2'

# %%
to_plot = best_lp_metrics_per_exp_config_df
to_plot[(to_plot['dataset_name'] == DATASET_NAME) & (to_plot['exp_config_name'].str.contains(CASE_STUDY_NAME, case=False, na=False))]
# Out:
# subgroup                                    exp_config_name  run_num  \
# 0         case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fai...        1
# 1         case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fai...        1
# 2         case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fai...        1
# 3         case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fai...        1
# 4         case_studies_exp_folk_emp_cs2_w_acc_0_25_w_fai...        1
# ..                                                      ...      ...
# 58        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...        5
# 59        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...        5
# 60        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...        5
# 61        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...        5
# 62        case_studies_exp_folk_emp_cs2_w_acc_0_75_w_fai...        5
#
# subgroup                              logical_pipeline_uuid  \
# 0         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 1         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 2         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 3         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 4         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# ..                                                      ...
# 58        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 59        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 60        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 61        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 62        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
#
# subgroup                physical_pipeline_uuid  compound_pp_quality  \
# 0         da36ca4c-359b-499f-a57c-51066e734e16             0.947287
# 1         da36ca4c-359b-499f-a57c-51066e734e16             0.947287
# 2         da36ca4c-359b-499f-a57c-51066e734e16             0.947287
# 3         da36ca4c-359b-499f-a57c-51066e734e16             0.947287
# 4         da36ca4c-359b-499f-a57c-51066e734e16             0.947287
# ..                                         ...                  ...
# 58        7b49dbd2-80c6-40f9-b08c-95c26a27c258             0.851214
# 59        7b49dbd2-80c6-40f9-b08c-95c26a27c258             0.851214
# 60        7b49dbd2-80c6-40f9-b08c-95c26a27c258             0.851214
# 61        7b49dbd2-80c6-40f9-b08c-95c26a27c258             0.851214
# 62        7b49dbd2-80c6-40f9-b08c-95c26a27c258             0.851214
#
# subgroup          metric   model_name  runtime_in_mins dataset_name  \
# 0               Accuracy  gandalf_clf         6.052121     folk_emp
# 1                     F1  gandalf_clf         6.052121     folk_emp
# 2                    FNR  gandalf_clf         6.052121     folk_emp
# 3                    FPR  gandalf_clf         6.052121     folk_emp
# 4                    PPV  gandalf_clf         6.052121     folk_emp
# ..                   ...          ...              ...          ...
# 58                   PPV  gandalf_clf         2.301869     folk_emp
# 59           Sample_Size  gandalf_clf         2.301869     folk_emp
# 60        Selection-Rate  gandalf_clf         2.301869     folk_emp
# 61                   TNR  gandalf_clf         2.301869     folk_emp
# 62                   TPR  gandalf_clf         2.301869     folk_emp
#
# subgroup                      logical_pipeline_name null_imputer_name  \
# 0         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 1         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 2         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 3         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 4         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# ..                                              ...               ...
# 58        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 59        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 60        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 61        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 62        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
#
# subgroup fairness_intervention_name    RAC1P_dis   RAC1P_priv  SEX&RAC1P_dis  \
# 0          NO_FAIRNESS_INTERVENTION     0.734973     0.737119       0.702509
# 1          NO_FAIRNESS_INTERVENTION     0.791994     0.790620       0.757310
# 2          NO_FAIRNESS_INTERVENTION     0.137072     0.137900       0.145215
# 3          NO_FAIRNESS_INTERVENTION     0.445175     0.432466       0.478431
# 4          NO_FAIRNESS_INTERVENTION     0.731836     0.730085       0.679790
# ..                              ...          ...          ...            ...
# 58         NO_FAIRNESS_INTERVENTION     0.723606     0.732959       0.673123
# 59         NO_FAIRNESS_INTERVENTION  1131.000000  1869.000000     579.000000
# 60         NO_FAIRNESS_INTERVENTION     0.745358     0.667202       0.713299
# 61         NO_FAIRNESS_INTERVENTION     0.517598     0.602151       0.501845
# 62         NO_FAIRNESS_INTERVENTION     0.941358     0.885659       0.902597
#
# subgroup  SEX&RAC1P_priv      SEX_dis     SEX_priv      overall
# 0               0.744062     0.705060     0.767690     0.736333
# 1               0.798582     0.752928     0.825476     0.791128
# 2               0.135983     0.136829     0.138220     0.137594
# 3               0.426587     0.466667     0.397790     0.437055
# 4               0.742361     0.667656     0.792108     0.730732
# ..                   ...          ...          ...          ...
# 58              0.742993     0.662149     0.794702     0.729187
# 59           2421.000000  1504.000000  1496.000000  3000.000000
# 60              0.692689     0.686835     0.706551     0.696667
# 61              0.589133     0.525815     0.628425     0.571212
# 62              0.908163     0.890625     0.921053     0.907143
#
# [135 rows x 19 columns]

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="F1")
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Selection_Rate_Difference",
                                           group=GROUP)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Case study 3

# %%
CASE_STUDY_NAME = 'cs3'

# %%
to_plot = best_lp_metrics_per_exp_config_df
to_plot[(to_plot['dataset_name'] == DATASET_NAME) & (to_plot['exp_config_name'].str.contains(CASE_STUDY_NAME, case=False, na=False))]
# Out:
# subgroup                                    exp_config_name  run_num  \
# 0         case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fai...        1
# 1         case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fai...        1
# 2         case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fai...        1
# 3         case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fai...        1
# 4         case_studies_exp_folk_emp_cs3_w_acc_0_25_w_fai...        1
# ..                                                      ...      ...
# 58        case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair...        5
# 59        case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair...        5
# 60        case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair...        5
# 61        case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair...        5
# 62        case_studies_exp_folk_emp_cs3_w_acc_0_5_w_fair...        5
#
# subgroup                              logical_pipeline_uuid  \
# 0         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 1         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 2         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 3         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 4         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# ..                                                      ...
# 58        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 59        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 60        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 61        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 62        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
#
# subgroup                physical_pipeline_uuid  compound_pp_quality  \
# 0         f794439c-604d-4917-8529-815b486c78cb             0.941727
# 1         f794439c-604d-4917-8529-815b486c78cb             0.941727
# 2         f794439c-604d-4917-8529-815b486c78cb             0.941727
# 3         f794439c-604d-4917-8529-815b486c78cb             0.941727
# 4         f794439c-604d-4917-8529-815b486c78cb             0.941727
# ..                                         ...                  ...
# 58        5c825f16-f64a-4b99-907c-92390f1af65c             0.890274
# 59        5c825f16-f64a-4b99-907c-92390f1af65c             0.890274
# 60        5c825f16-f64a-4b99-907c-92390f1af65c             0.890274
# 61        5c825f16-f64a-4b99-907c-92390f1af65c             0.890274
# 62        5c825f16-f64a-4b99-907c-92390f1af65c             0.890274
#
# subgroup          metric   model_name  runtime_in_mins dataset_name  \
# 0               Accuracy  gandalf_clf         2.797050     folk_emp
# 1                     F1  gandalf_clf         2.797050     folk_emp
# 2                    FNR  gandalf_clf         2.797050     folk_emp
# 3                    FPR  gandalf_clf         2.797050     folk_emp
# 4                    PPV  gandalf_clf         2.797050     folk_emp
# ..                   ...          ...              ...          ...
# 58                   PPV  gandalf_clf         3.508396     folk_emp
# 59           Sample_Size  gandalf_clf         3.508396     folk_emp
# 60        Selection-Rate  gandalf_clf         3.508396     folk_emp
# 61                   TNR  gandalf_clf         3.508396     folk_emp
# 62                   TPR  gandalf_clf         3.508396     folk_emp
#
# subgroup                      logical_pipeline_name null_imputer_name  \
# 0         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 1         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 2         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 3         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 4         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# ..                                              ...               ...
# 58        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 59        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 60        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 61        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 62        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
#
# subgroup fairness_intervention_name    RAC1P_dis   RAC1P_priv  SEX&RAC1P_dis  \
# 0          NO_FAIRNESS_INTERVENTION     0.737705     0.737119       0.718638
# 1          NO_FAIRNESS_INTERVENTION     0.788546     0.782609       0.763198
# 2          NO_FAIRNESS_INTERVENTION     0.163551     0.178082       0.165017
# 3          NO_FAIRNESS_INTERVENTION     0.401316     0.377943       0.419608
# 4          NO_FAIRNESS_INTERVENTION     0.745833     0.746888       0.702778
# ..                              ...          ...          ...            ...
# 58         NO_FAIRNESS_INTERVENTION     0.719527     0.730274       0.670644
# 59         NO_FAIRNESS_INTERVENTION  1131.000000  1869.000000     579.000000
# 60         NO_FAIRNESS_INTERVENTION     0.747126     0.664526       0.723661
# 61         NO_FAIRNESS_INTERVENTION     0.509317     0.599761       0.490775
# 62         NO_FAIRNESS_INTERVENTION     0.938272     0.878876       0.912338
#
# subgroup  SEX&RAC1P_priv      SEX_dis     SEX_priv      overall
# 0               0.741605     0.717044     0.757677     0.737333
# 1               0.789597     0.752763     0.813176     0.784817
# 2               0.174338     0.172634     0.172775     0.172712
# 3               0.377976     0.402778     0.364641     0.386382
# 4               0.756550     0.690502     0.799595     0.746494
# ..                   ...          ...          ...          ...
# 58              0.739808     0.658937     0.791825     0.725922
# 59           2421.000000  1504.000000  1496.000000  3000.000000
# 60              0.688971     0.688165     0.703209     0.695667
# 61              0.586273     0.520380     0.625000     0.566667
# 62              0.899417     0.888021     0.913377     0.901786
#
# [180 rows x 19 columns]

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="F1")
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Equalized_Odds_FNR",
                                           group=GROUP)
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Selection_Rate_Difference",
                                           group=GROUP)
# Out:
# alt.Chart(...)
