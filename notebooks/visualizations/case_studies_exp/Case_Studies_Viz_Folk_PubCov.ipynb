# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings

warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "virny-flow-experiments":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/Research/NYU/VirnyFlow_Project/Code/virny-flow-experiments

# %% [markdown]
# # Case Studies Visualizations

# %%
from duckdb import query as sqldf
from source.visualizations.use_case_queries import get_best_lps_per_exp_config
from source.visualizations.cost_model_viz import (create_box_plot_per_dataset_and_case_study,
                                                  create_box_plot_per_dataset_and_all_case_studies,
                                                  create_concat_box_plot_per_dataset_and_all_case_studies)

# %% [markdown]
# ## Prepare data for visualizations

# %%
SECRETS_PATH = os.path.join(os.getcwd(), "scripts", "configs", "secrets.env")
EXP_NAME = 'case_studies_exp'
DATASET_NAME = 'folk_pubcov'
EXP_CONFIG_NAMES = [
    "case_studies_exp_folk_pubcov_cs1_w_acc_0_25_w_fair_0_75",
    "case_studies_exp_folk_pubcov_cs1_w_acc_0_5_w_fair_0_5",
    "case_studies_exp_folk_pubcov_cs1_w_acc_0_75_w_fair_0_25",
    "case_studies_exp_folk_pubcov_cs2_w_acc_0_25_w_fair_0_75",
    "case_studies_exp_folk_pubcov_cs2_w_acc_0_5_w_fair_0_5",
    "case_studies_exp_folk_pubcov_cs2_w_acc_0_75_w_fair_0_25",
    "case_studies_exp_folk_pubcov_cs3_w_acc_0_25_w_fair1_0_25_w_fair2_0_5",
    "case_studies_exp_folk_pubcov_cs3_w_acc_0_25_w_fair1_0_5_w_fair2_0_25",
    "case_studies_exp_folk_pubcov_cs3_w_acc_0_33_w_fair1_0_33_w_fair2_0_33",
    "case_studies_exp_folk_pubcov_cs3_w_acc_0_5_w_fair1_0_25_w_fair2_0_25",
]

# %%
best_lp_metrics_per_exp_config_df = get_best_lps_per_exp_config(secrets_path=SECRETS_PATH, exp_config_names=EXP_CONFIG_NAMES)
# Out:
# Extracting metrics for case_studies_exp_folk_pubcov_cs1_w_acc_0_25_w_fair_0_75...
# best_pps_per_lp_and_run_num_df.shape: (81, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_pubcov_cs1_w_acc_0_25_w_fair_0_75
#
# Extracting metrics for case_studies_exp_folk_pubcov_cs1_w_acc_0_5_w_fair_0_5...
# best_pps_per_lp_and_run_num_df.shape: (63, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_pubcov_cs1_w_acc_0_5_w_fair_0_5
#
# Extracting metrics for case_studies_exp_folk_pubcov_cs1_w_acc_0_75_w_fair_0_25...
# best_pps_per_lp_and_run_num_df.shape: (63, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_pubcov_cs1_w_acc_0_75_w_fair_0_25
#
# Extracting metrics for case_studies_exp_folk_pubcov_cs2_w_acc_0_25_w_fair_0_75...
# best_pps_per_lp_and_run_num_df.shape: (90, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_pubcov_cs2_w_acc_0_25_w_fair_0_75
#
# Extracting metrics for case_studies_exp_folk_pubcov_cs2_w_acc_0_5_w_fair_0_5...
# best_pps_per_lp_and_run_num_df.shape: (54, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_pubcov_cs2_w_acc_0_5_w_fair_0_5
#
# Extracting metrics for case_studies_exp_folk_pubcov_cs2_w_acc_0_75_w_fair_0_25...
# best_pps_per_lp_and_run_num_df.shape: (54, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_pubcov_cs2_w_acc_0_75_w_fair_0_25
#
# Extracting metrics for case_studies_exp_folk_pubcov_cs3_w_acc_0_25_w_fair1_0_25_w_fair2_0_5...
# best_pps_per_lp_and_run_num_df.shape: (99, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_pubcov_cs3_w_acc_0_25_w_fair1_0_25_w_fair2_0_5
#
# Extracting metrics for case_studies_exp_folk_pubcov_cs3_w_acc_0_25_w_fair1_0_5_w_fair2_0_25...
# best_pps_per_lp_and_run_num_df.shape: (72, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_pubcov_cs3_w_acc_0_25_w_fair1_0_5_w_fair2_0_25
#
# Extracting metrics for case_studies_exp_folk_pubcov_cs3_w_acc_0_33_w_fair1_0_33_w_fair2_0_33...
# best_pps_per_lp_and_run_num_df.shape: (54, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_pubcov_cs3_w_acc_0_33_w_fair1_0_33_w_fair2_0_33
#
# Extracting metrics for case_studies_exp_folk_pubcov_cs3_w_acc_0_5_w_fair1_0_25_w_fair2_0_25...
# best_pps_per_lp_and_run_num_df.shape: (54, 19)
# best_lp_per_run_all.shape: (45, 19)
# Extracted metrics for case_studies_exp_folk_pubcov_cs3_w_acc_0_5_w_fair1_0_25_w_fair2_0_25

# %%
best_lp_metrics_per_exp_config_df.shape
# Out:
# (450, 19)

# %%
best_lp_metrics_per_exp_config_df.head()
# Out:
# subgroup                                    exp_config_name  run_num  \
# 0         case_studies_exp_folk_pubcov_cs1_w_acc_0_25_w_...        1
# 1         case_studies_exp_folk_pubcov_cs1_w_acc_0_25_w_...        1
# 2         case_studies_exp_folk_pubcov_cs1_w_acc_0_25_w_...        1
# 3         case_studies_exp_folk_pubcov_cs1_w_acc_0_25_w_...        1
# 4         case_studies_exp_folk_pubcov_cs1_w_acc_0_25_w_...        1
#
# subgroup                              logical_pipeline_uuid  \
# 0         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 1         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 2         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 3         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 4         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
#
# subgroup                physical_pipeline_uuid  compound_pp_quality    metric  \
# 0         958a42d4-ae13-4272-ac55-7a7a43adb079             0.903676  Accuracy
# 1         958a42d4-ae13-4272-ac55-7a7a43adb079             0.903676        F1
# 2         958a42d4-ae13-4272-ac55-7a7a43adb079             0.903676       FNR
# 3         958a42d4-ae13-4272-ac55-7a7a43adb079             0.903676       FPR
# 4         958a42d4-ae13-4272-ac55-7a7a43adb079             0.903676       PPV
#
# subgroup   model_name  runtime_in_mins dataset_name  \
# 0         gandalf_clf         7.397554  folk_pubcov
# 1         gandalf_clf         7.397554  folk_pubcov
# 2         gandalf_clf         7.397554  folk_pubcov
# 3         gandalf_clf         7.397554  folk_pubcov
# 4         gandalf_clf         7.397554  folk_pubcov
#
# subgroup                      logical_pipeline_name null_imputer_name  \
# 0         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 1         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 2         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 3         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 4         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
#
# subgroup fairness_intervention_name  RAC1P_dis  RAC1P_priv  SEX&RAC1P_dis  \
# 0          NO_FAIRNESS_INTERVENTION   0.655832    0.751981       0.653771
# 1          NO_FAIRNESS_INTERVENTION   0.618647    0.625122       0.629649
# 2          NO_FAIRNESS_INTERVENTION   0.421196    0.404562       0.398398
# 3          NO_FAIRNESS_INTERVENTION   0.272405    0.164726       0.296261
# 4          NO_FAIRNESS_INTERVENTION   0.664379    0.657922       0.660440
#
# subgroup  SEX&RAC1P_priv   SEX_dis  SEX_priv   overall
# 0               0.731088  0.719370  0.710138  0.715300
# 1               0.619623  0.619636  0.625220  0.622163
# 2               0.416862  0.405028  0.420652  0.412237
# 3               0.179915  0.203021  0.196185  0.200100
# 4               0.660978  0.646434  0.678981  0.660840

# %% [markdown]
# ## Get the best lp per exp config

# %%
# Get best lp per exp config
sqldf("""
    SELECT DISTINCT exp_config_name, logical_pipeline_name
    FROM best_lp_metrics_per_exp_config_df
""").to_df()
# Out:
#                                       exp_config_name  \
# 0   case_studies_exp_folk_pubcov_cs3_w_acc_0_33_w_...
# 1   case_studies_exp_folk_pubcov_cs1_w_acc_0_5_w_f...
# 2   case_studies_exp_folk_pubcov_cs2_w_acc_0_25_w_...
# 3   case_studies_exp_folk_pubcov_cs3_w_acc_0_25_w_...
# 4   case_studies_exp_folk_pubcov_cs3_w_acc_0_5_w_f...
# 5   case_studies_exp_folk_pubcov_cs1_w_acc_0_75_w_...
# 6   case_studies_exp_folk_pubcov_cs2_w_acc_0_5_w_f...
# 7   case_studies_exp_folk_pubcov_cs2_w_acc_0_75_w_...
# 8   case_studies_exp_folk_pubcov_cs3_w_acc_0_25_w_...
# 9   case_studies_exp_folk_pubcov_cs1_w_acc_0_25_w_...
# 10  case_studies_exp_folk_pubcov_cs2_w_acc_0_5_w_f...
# 11  case_studies_exp_folk_pubcov_cs2_w_acc_0_75_w_...
# 12  case_studies_exp_folk_pubcov_cs3_w_acc_0_25_w_...
# 13  case_studies_exp_folk_pubcov_cs1_w_acc_0_25_w_...
# 14  case_studies_exp_folk_pubcov_cs1_w_acc_0_5_w_f...
# 15  case_studies_exp_folk_pubcov_cs3_w_acc_0_25_w_...
# 16  case_studies_exp_folk_pubcov_cs3_w_acc_0_5_w_f...
# 17  case_studies_exp_folk_pubcov_cs3_w_acc_0_33_w_...
#
#                         logical_pipeline_name
# 0      None&NO_FAIRNESS_INTERVENTION&lgbm_clf
# 1      None&NO_FAIRNESS_INTERVENTION&lgbm_clf
# 2        None&NO_FAIRNESS_INTERVENTION&rf_clf
# 3   None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 4   None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 5   None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 6   None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 7      None&NO_FAIRNESS_INTERVENTION&lgbm_clf
# 8        None&NO_FAIRNESS_INTERVENTION&rf_clf
# 9        None&NO_FAIRNESS_INTERVENTION&rf_clf
# 10     None&NO_FAIRNESS_INTERVENTION&lgbm_clf
# 11  None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 12  None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 13  None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 14  None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 15       None&NO_FAIRNESS_INTERVENTION&rf_clf
# 16     None&NO_FAIRNESS_INTERVENTION&lgbm_clf
# 17  None&NO_FAIRNESS_INTERVENTION&gandalf_clf

# %% [markdown]
# ## All Case Studies

# %%
rename_legend_dct = {
    "cs1_acc_0.25_fair_0.75": "CS1: F1=0.25, SRD(sex)=0.75",
    "cs1_acc_0.5_fair_0.5": "CS1: F1=0.5, SRD(sex)=0.5",
    "cs1_acc_0.75_fair_0.25": "CS1: F1=0.75, SRD(sex)=0.25",
    "cs2_acc_0.25_fair_0.75": "CS2: F1=0.25, SRD(race)=0.75",
    "cs2_acc_0.5_fair_0.5": "CS2: F1=0.5, SRD(race)=0.5",
    "cs2_acc_0.75_fair_0.25": "CS2: F1=0.75, SRD(race)=0.25",
    "cs3_acc_0.25_fair1_0.25_fair2_0.5": "CS3: F1=0.25, SRD(sex)=0.25, SRD(race)=0.5",
    "cs3_acc_0.25_fair1_0.5_fair2_0.25": "CS3: F1=0.25, SRD(sex)=0.5, SRD(race)=0.25",
    "cs3_acc_0.33_fair1_0.33_fair2_0.33": "CS3: F1=0.33, SRD(sex)=0.33, SRD(race)=0.33",
    "cs3_acc_0.5_fair1_0.25_fair2_0.25": "CS3: F1=0.5, SRD(sex)=0.25, SRD(race)=0.25",
}

# %%
create_concat_box_plot_per_dataset_and_all_case_studies(to_plot=best_lp_metrics_per_exp_config_df,
                                                        exp_name=EXP_NAME,
                                                        dataset_name=DATASET_NAME,
                                                        metric1="F1",
                                                        group1="overall",
                                                        metric2="Selection_Rate_Difference",
                                                        group2="SEX",
                                                        metric3="Selection_Rate_Difference",
                                                        group3="RAC1P",
                                                        rename_legend_dct=rename_legend_dct)
# Out:
# alt.HConcatChart(...)

# %%
create_box_plot_per_dataset_and_all_case_studies(to_plot=best_lp_metrics_per_exp_config_df,
                                                 exp_name=EXP_NAME,
                                                 dataset_name=DATASET_NAME,
                                                 metric_x="F1",
                                                 group_x="overall",
                                                 metric_y="Selection_Rate_Difference",
                                                 group_y="SEX",
                                                 rename_legend_dct=rename_legend_dct)
# Out:
# alt.LayerChart(...)

# %%
create_box_plot_per_dataset_and_all_case_studies(to_plot=best_lp_metrics_per_exp_config_df,
                                                 exp_name=EXP_NAME,
                                                 dataset_name=DATASET_NAME,
                                                 metric_x="F1",
                                                 group_x="overall",
                                                 metric_y="Selection_Rate_Difference",
                                                 group_y="RAC1P",
                                                 rename_legend_dct=rename_legend_dct)
# Out:
# alt.LayerChart(...)

# %%
create_box_plot_per_dataset_and_all_case_studies(to_plot=best_lp_metrics_per_exp_config_df,
                                                 exp_name=EXP_NAME,
                                                 dataset_name=DATASET_NAME,
                                                 metric_x="Accuracy",
                                                 group_x="overall",
                                                 metric_y="Selection_Rate_Difference",
                                                 group_y="RAC1P",
                                                 rename_legend_dct=rename_legend_dct)
# Out:
# alt.LayerChart(...)

# %%
create_box_plot_per_dataset_and_all_case_studies(to_plot=best_lp_metrics_per_exp_config_df,
                                                 exp_name=EXP_NAME,
                                                 dataset_name=DATASET_NAME,
                                                 metric_x="Selection_Rate_Difference",
                                                 group_x="SEX",
                                                 metric_y="Selection_Rate_Difference",
                                                 group_y="RAC1P",
                                                 rename_legend_dct=rename_legend_dct)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Case study 1

# %%
CASE_STUDY_NAME = 'cs1'

# %%
to_plot = best_lp_metrics_per_exp_config_df
to_plot[(to_plot['dataset_name'] == DATASET_NAME) & (to_plot['exp_config_name'].str.contains(CASE_STUDY_NAME, case=False, na=False))]
# Out:
# subgroup                                    exp_config_name  run_num  \
# 0         case_studies_exp_folk_pubcov_cs1_w_acc_0_25_w_...        1
# 1         case_studies_exp_folk_pubcov_cs1_w_acc_0_25_w_...        1
# 2         case_studies_exp_folk_pubcov_cs1_w_acc_0_25_w_...        1
# 3         case_studies_exp_folk_pubcov_cs1_w_acc_0_25_w_...        1
# 4         case_studies_exp_folk_pubcov_cs1_w_acc_0_25_w_...        1
# ..                                                      ...      ...
# 49        case_studies_exp_folk_pubcov_cs1_w_acc_0_75_w_...        5
# 50        case_studies_exp_folk_pubcov_cs1_w_acc_0_75_w_...        5
# 51        case_studies_exp_folk_pubcov_cs1_w_acc_0_75_w_...        5
# 52        case_studies_exp_folk_pubcov_cs1_w_acc_0_75_w_...        5
# 53        case_studies_exp_folk_pubcov_cs1_w_acc_0_75_w_...        5
#
# subgroup                              logical_pipeline_uuid  \
# 0         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 1         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 2         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 3         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 4         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# ..                                                      ...
# 49        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 50        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 51        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 52        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 53        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
#
# subgroup                physical_pipeline_uuid  compound_pp_quality  \
# 0         958a42d4-ae13-4272-ac55-7a7a43adb079             0.903676
# 1         958a42d4-ae13-4272-ac55-7a7a43adb079             0.903676
# 2         958a42d4-ae13-4272-ac55-7a7a43adb079             0.903676
# 3         958a42d4-ae13-4272-ac55-7a7a43adb079             0.903676
# 4         958a42d4-ae13-4272-ac55-7a7a43adb079             0.903676
# ..                                         ...                  ...
# 49        68bd4be6-838e-4843-929f-0d7464c89b53             0.730581
# 50        68bd4be6-838e-4843-929f-0d7464c89b53             0.730581
# 51        68bd4be6-838e-4843-929f-0d7464c89b53             0.730581
# 52        68bd4be6-838e-4843-929f-0d7464c89b53             0.730581
# 53        68bd4be6-838e-4843-929f-0d7464c89b53             0.730581
#
# subgroup          metric   model_name  runtime_in_mins dataset_name  \
# 0               Accuracy  gandalf_clf         7.397554  folk_pubcov
# 1                     F1  gandalf_clf         7.397554  folk_pubcov
# 2                    FNR  gandalf_clf         7.397554  folk_pubcov
# 3                    FPR  gandalf_clf         7.397554  folk_pubcov
# 4                    PPV  gandalf_clf         7.397554  folk_pubcov
# ..                   ...          ...              ...          ...
# 49                   PPV  gandalf_clf        10.655986  folk_pubcov
# 50           Sample_Size  gandalf_clf        10.655986  folk_pubcov
# 51        Selection-Rate  gandalf_clf        10.655986  folk_pubcov
# 52                   TNR  gandalf_clf        10.655986  folk_pubcov
# 53                   TPR  gandalf_clf        10.655986  folk_pubcov
#
# subgroup                      logical_pipeline_name null_imputer_name  \
# 0         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 1         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 2         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 3         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 4         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# ..                                              ...               ...
# 49        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 50        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 51        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 52        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 53        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
#
# subgroup fairness_intervention_name    RAC1P_dis   RAC1P_priv  SEX&RAC1P_dis  \
# 0          NO_FAIRNESS_INTERVENTION     0.655832     0.751981       0.653771
# 1          NO_FAIRNESS_INTERVENTION     0.618647     0.625122       0.629649
# 2          NO_FAIRNESS_INTERVENTION     0.421196     0.404562       0.398398
# 3          NO_FAIRNESS_INTERVENTION     0.272405     0.164726       0.296261
# 4          NO_FAIRNESS_INTERVENTION     0.664379     0.657922       0.660440
# ..                              ...          ...          ...            ...
# 49         NO_FAIRNESS_INTERVENTION     0.666097     0.650748       0.685509
# 50         NO_FAIRNESS_INTERVENTION  3688.000000  6312.000000    2023.000000
# 51         NO_FAIRNESS_INTERVENTION     0.475868     0.328422       0.480969
# 52         NO_FAIRNESS_INTERVENTION     0.696216     0.826087       0.703201
# 53         NO_FAIRNESS_INTERVENTION     0.664582     0.627734       0.672379
#
# subgroup  SEX&RAC1P_priv      SEX_dis     SEX_priv       overall
# 0               0.731088     0.719370     0.710138      0.715300
# 1               0.619623     0.619636     0.625220      0.622163
# 2               0.416862     0.405028     0.420652      0.412237
# 3               0.179915     0.203021     0.196185      0.200100
# 4               0.660978     0.646434     0.678981      0.660840
# ..                   ...          ...          ...           ...
# 49              0.648336     0.656816     0.658960      0.657785
# 50           7977.000000  5677.000000  4323.000000  10000.000000
# 51              0.357904     0.369561     0.400185      0.382800
# 52              0.801620     0.795105     0.771140      0.784964
# 53              0.634774     0.637078     0.653295      0.644319
#
# [135 rows x 19 columns]

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="F1")
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Selection_Rate_Difference",
                                           group="SEX")
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Case study 2

# %%
CASE_STUDY_NAME = 'cs2'

# %%
to_plot = best_lp_metrics_per_exp_config_df
to_plot[(to_plot['dataset_name'] == DATASET_NAME) & (to_plot['exp_config_name'].str.contains(CASE_STUDY_NAME, case=False, na=False))]
# Out:
# subgroup                                    exp_config_name  run_num  \
# 9         case_studies_exp_folk_pubcov_cs2_w_acc_0_25_w_...        1
# 10        case_studies_exp_folk_pubcov_cs2_w_acc_0_25_w_...        1
# 11        case_studies_exp_folk_pubcov_cs2_w_acc_0_25_w_...        1
# 12        case_studies_exp_folk_pubcov_cs2_w_acc_0_25_w_...        1
# 13        case_studies_exp_folk_pubcov_cs2_w_acc_0_25_w_...        1
# ..                                                      ...      ...
# 40        case_studies_exp_folk_pubcov_cs2_w_acc_0_75_w_...        5
# 41        case_studies_exp_folk_pubcov_cs2_w_acc_0_75_w_...        5
# 42        case_studies_exp_folk_pubcov_cs2_w_acc_0_75_w_...        5
# 43        case_studies_exp_folk_pubcov_cs2_w_acc_0_75_w_...        5
# 44        case_studies_exp_folk_pubcov_cs2_w_acc_0_75_w_...        5
#
# subgroup                              logical_pipeline_uuid  \
# 9          Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 10         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 11         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 12         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 13         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# ..                                                      ...
# 40        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 41        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 42        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 43        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 44        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
#
# subgroup                physical_pipeline_uuid  compound_pp_quality  \
# 9         613fde51-0194-4263-98e5-5e6f95e37576             0.868405
# 10        613fde51-0194-4263-98e5-5e6f95e37576             0.868405
# 11        613fde51-0194-4263-98e5-5e6f95e37576             0.868405
# 12        613fde51-0194-4263-98e5-5e6f95e37576             0.868405
# 13        613fde51-0194-4263-98e5-5e6f95e37576             0.868405
# ..                                         ...                  ...
# 40        5e2306d5-6b18-4a5b-9e0d-c009908f5af7             0.703187
# 41        5e2306d5-6b18-4a5b-9e0d-c009908f5af7             0.703187
# 42        5e2306d5-6b18-4a5b-9e0d-c009908f5af7             0.703187
# 43        5e2306d5-6b18-4a5b-9e0d-c009908f5af7             0.703187
# 44        5e2306d5-6b18-4a5b-9e0d-c009908f5af7             0.703187
#
# subgroup          metric   model_name  runtime_in_mins dataset_name  \
# 9               Accuracy       rf_clf         0.044582  folk_pubcov
# 10                    F1       rf_clf         0.044582  folk_pubcov
# 11                   FNR       rf_clf         0.044582  folk_pubcov
# 12                   FPR       rf_clf         0.044582  folk_pubcov
# 13                   PPV       rf_clf         0.044582  folk_pubcov
# ..                   ...          ...              ...          ...
# 40                   PPV  gandalf_clf         9.254831  folk_pubcov
# 41           Sample_Size  gandalf_clf         9.254831  folk_pubcov
# 42        Selection-Rate  gandalf_clf         9.254831  folk_pubcov
# 43                   TNR  gandalf_clf         9.254831  folk_pubcov
# 44                   TPR  gandalf_clf         9.254831  folk_pubcov
#
# subgroup                      logical_pipeline_name null_imputer_name  \
# 9              None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 10             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 11             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 12             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 13             None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# ..                                              ...               ...
# 40        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 41        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 42        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 43        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 44        None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
#
# subgroup fairness_intervention_name    RAC1P_dis   RAC1P_priv  SEX&RAC1P_dis  \
# 9          NO_FAIRNESS_INTERVENTION     0.623067     0.751657       0.622919
# 10         NO_FAIRNESS_INTERVENTION     0.442203     0.534827       0.440407
# 11         NO_FAIRNESS_INTERVENTION     0.690217     0.588920       0.696697
# 12         NO_FAIRNESS_INTERVENTION     0.085063     0.067129       0.070949
# 13         NO_FAIRNESS_INTERVENTION     0.772358     0.765165       0.803714
# ..                              ...          ...          ...            ...
# 40         NO_FAIRNESS_INTERVENTION     0.667042     0.643972       0.687436
# 41         NO_FAIRNESS_INTERVENTION  3688.000000  6312.000000    2023.000000
# 42         NO_FAIRNESS_INTERVENTION     0.481291     0.335076       0.483935
# 43         NO_FAIRNESS_INTERVENTION     0.693624     0.819121       0.703201
# 44         NO_FAIRNESS_INTERVENTION     0.673110     0.633783       0.678427
#
# subgroup  SEX&RAC1P_priv      SEX_dis     SEX_priv       overall
# 9               0.723046     0.708281     0.695396      0.702600
# 10              0.510657     0.474380     0.516385      0.494218
# 11              0.615256     0.657356     0.610326      0.635657
# 12              0.073455     0.063607     0.085636      0.073021
# 13              0.759076     0.770681     0.765208      0.767970
# ..                   ...          ...          ...           ...
# 40              0.643422     0.653377     0.655859      0.654499
# 41           7977.000000  5677.000000  4323.000000  10000.000000
# 42              0.364924     0.375550     0.406662      0.389000
# 43              0.794902     0.789698     0.765322      0.779383
# 44              0.642318     0.644013     0.660745      0.651484
#
# [135 rows x 19 columns]

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="F1")
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Selection_Rate_Difference",
                                           group="RAC1P")
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Case study 3

# %%
CASE_STUDY_NAME = 'cs3'

# %%
to_plot = best_lp_metrics_per_exp_config_df
to_plot[(to_plot['dataset_name'] == DATASET_NAME) & (to_plot['exp_config_name'].str.contains(CASE_STUDY_NAME, case=False, na=False))]
# Out:
# subgroup                                    exp_config_name  run_num  \
# 0         case_studies_exp_folk_pubcov_cs3_w_acc_0_25_w_...        1
# 1         case_studies_exp_folk_pubcov_cs3_w_acc_0_25_w_...        1
# 2         case_studies_exp_folk_pubcov_cs3_w_acc_0_25_w_...        1
# 3         case_studies_exp_folk_pubcov_cs3_w_acc_0_25_w_...        1
# 4         case_studies_exp_folk_pubcov_cs3_w_acc_0_25_w_...        1
# ..                                                      ...      ...
# 49        case_studies_exp_folk_pubcov_cs3_w_acc_0_5_w_f...        5
# 50        case_studies_exp_folk_pubcov_cs3_w_acc_0_5_w_f...        5
# 51        case_studies_exp_folk_pubcov_cs3_w_acc_0_5_w_f...        5
# 52        case_studies_exp_folk_pubcov_cs3_w_acc_0_5_w_f...        5
# 53        case_studies_exp_folk_pubcov_cs3_w_acc_0_5_w_f...        5
#
# subgroup                              logical_pipeline_uuid  \
# 0         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 1         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 2         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 3         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 4         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# ..                                                      ...
# 49        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 50        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 51        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 52        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
# 53        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mbGdibV...
#
# subgroup                physical_pipeline_uuid  compound_pp_quality  \
# 0         05d71541-ac33-4fd8-8d8b-e87e90dced47             0.867225
# 1         05d71541-ac33-4fd8-8d8b-e87e90dced47             0.867225
# 2         05d71541-ac33-4fd8-8d8b-e87e90dced47             0.867225
# 3         05d71541-ac33-4fd8-8d8b-e87e90dced47             0.867225
# 4         05d71541-ac33-4fd8-8d8b-e87e90dced47             0.867225
# ..                                         ...                  ...
# 49        10b90999-c1e0-47e5-b15c-3894fefe112f             0.787019
# 50        10b90999-c1e0-47e5-b15c-3894fefe112f             0.787019
# 51        10b90999-c1e0-47e5-b15c-3894fefe112f             0.787019
# 52        10b90999-c1e0-47e5-b15c-3894fefe112f             0.787019
# 53        10b90999-c1e0-47e5-b15c-3894fefe112f             0.787019
#
# subgroup          metric   model_name  runtime_in_mins dataset_name  \
# 0               Accuracy  gandalf_clf        10.236690  folk_pubcov
# 1                     F1  gandalf_clf        10.236690  folk_pubcov
# 2                    FNR  gandalf_clf        10.236690  folk_pubcov
# 3                    FPR  gandalf_clf        10.236690  folk_pubcov
# 4                    PPV  gandalf_clf        10.236690  folk_pubcov
# ..                   ...          ...              ...          ...
# 49                   PPV     lgbm_clf         0.012929  folk_pubcov
# 50           Sample_Size     lgbm_clf         0.012929  folk_pubcov
# 51        Selection-Rate     lgbm_clf         0.012929  folk_pubcov
# 52                   TNR     lgbm_clf         0.012929  folk_pubcov
# 53                   TPR     lgbm_clf         0.012929  folk_pubcov
#
# subgroup                      logical_pipeline_name null_imputer_name  \
# 0         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 1         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 2         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 3         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 4         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# ..                                              ...               ...
# 49           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 50           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 51           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 52           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
# 53           None&NO_FAIRNESS_INTERVENTION&lgbm_clf              None
#
# subgroup fairness_intervention_name    RAC1P_dis   RAC1P_priv  SEX&RAC1P_dis  \
# 0          NO_FAIRNESS_INTERVENTION     0.635387     0.750040       0.646425
# 1          NO_FAIRNESS_INTERVENTION     0.516846     0.569839       0.544767
# 2          NO_FAIRNESS_INTERVENTION     0.595652     0.523277       0.567568
# 3          NO_FAIRNESS_INTERVENTION     0.149367     0.104533       0.148610
# 4          NO_FAIRNESS_INTERVENTION     0.716073     0.708160       0.735945
# ..                              ...          ...          ...            ...
# 49         NO_FAIRNESS_INTERVENTION     0.720000     0.693265       0.739018
# 50         NO_FAIRNESS_INTERVENTION  3688.000000  6312.000000    2023.000000
# 51         NO_FAIRNESS_INTERVENTION     0.372831     0.279943       0.382600
# 52         NO_FAIRNESS_INTERVENTION     0.800415     0.869805       0.804074
# 53         NO_FAIRNESS_INTERVENTION     0.562820     0.570033       0.576613
#
# subgroup  SEX&RAC1P_priv      SEX_dis     SEX_priv       overall
# 0               0.721664     0.718834     0.690406      0.706300
# 1               0.546757     0.555681     0.534923      0.546269
# 2               0.553028     0.542365     0.573370      0.556670
# 3               0.113101     0.118211     0.120670      0.119261
# 4               0.703899     0.707194     0.716895      0.711469
# ..                   ...          ...          ...           ...
# 49              0.693834     0.703725     0.706514      0.704965
# 50           7977.000000  5677.000000  4323.000000  10000.000000
# 51              0.296853     0.307381     0.323155      0.314200
# 52              0.856748     0.852874     0.840962      0.847833
# 53              0.563443     0.567730     0.565616      0.566786
#
# [180 rows x 19 columns]

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="F1")
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Selection_Rate_Difference",
                                           group="SEX")
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Selection_Rate_Difference",
                                           group="RAC1P")
# Out:
# alt.Chart(...)
