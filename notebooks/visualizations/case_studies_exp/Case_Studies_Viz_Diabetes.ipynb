# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings

warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "virny-flow-experiments":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/Research/NYU/VirnyFlow_Project/Code/virny-flow-experiments

# %% [markdown]
# # Case Studies Visualizations

# %%
from duckdb import query as sqldf
from source.visualizations.use_case_queries import get_best_lps_per_exp_config
from source.visualizations.cost_model_viz import create_box_plot_per_dataset_and_case_study

# %% [markdown]
# ## Prepare data for visualizations

# %%
SECRETS_PATH = os.path.join(os.getcwd(), "scripts", "configs", "secrets.env")
EXP_NAME = 'case_studies_exp'
DATASET_NAME = 'diabetes'
GROUP = "Gender"
EXP_CONFIG_NAMES = [
    "case_studies_exp_diabetes_cs1_w_acc_0_25_w_fair_0_75",
    "case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair_0_5",
    "case_studies_exp_diabetes_cs1_w_acc_0_75_w_fair_0_25",
    "case_studies_exp_diabetes_cs2_w_acc_0_25_w_stab_0_75",
    "case_studies_exp_diabetes_cs2_w_acc_0_5_w_stab_0_5",
    "case_studies_exp_diabetes_cs2_w_acc_0_75_w_stab_0_25",
    "case_studies_exp_diabetes_cs3_w_acc_0_25_w_fair_0_25_w_stab_0_5",
    "case_studies_exp_diabetes_cs3_w_acc_0_25_w_fair_0_5_w_stab_0_25",
    "case_studies_exp_diabetes_cs3_w_acc_0_5_w_fair_0_25_w_stab_0_25",
    "case_studies_exp_diabetes_cs3_w_acc_0_33_w_fair_0_33_w_stab_0_33",
]

# %%
best_lp_metrics_per_exp_config_df = get_best_lps_per_exp_config(secrets_path=SECRETS_PATH, exp_config_names=EXP_CONFIG_NAMES)
# Out:
# Extracting metrics for case_studies_exp_diabetes_cs1_w_acc_0_25_w_fair_0_75...
# best_pps_per_lp_and_run_num_df.shape: (117, 15)
# best_lp_per_run_all.shape: (45, 15)
# Extracted metrics for case_studies_exp_diabetes_cs1_w_acc_0_25_w_fair_0_75
#
# Extracting metrics for case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair_0_5...
# best_pps_per_lp_and_run_num_df.shape: (117, 15)
# best_lp_per_run_all.shape: (54, 15)
# Extracted metrics for case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair_0_5
#
# Extracting metrics for case_studies_exp_diabetes_cs1_w_acc_0_75_w_fair_0_25...
# best_pps_per_lp_and_run_num_df.shape: (117, 15)
# best_lp_per_run_all.shape: (54, 15)
# Extracted metrics for case_studies_exp_diabetes_cs1_w_acc_0_75_w_fair_0_25
#
# Extracting metrics for case_studies_exp_diabetes_cs2_w_acc_0_25_w_stab_0_75...
# best_pps_per_lp_and_run_num_df.shape: (216, 15)
# best_lp_per_run_all.shape: (90, 15)
# Extracted metrics for case_studies_exp_diabetes_cs2_w_acc_0_25_w_stab_0_75
#
# Extracting metrics for case_studies_exp_diabetes_cs2_w_acc_0_5_w_stab_0_5...
# best_pps_per_lp_and_run_num_df.shape: (198, 15)
# best_lp_per_run_all.shape: (90, 15)
# Extracted metrics for case_studies_exp_diabetes_cs2_w_acc_0_5_w_stab_0_5
#
# Extracting metrics for case_studies_exp_diabetes_cs2_w_acc_0_75_w_stab_0_25...
# best_pps_per_lp_and_run_num_df.shape: (180, 15)
# best_lp_per_run_all.shape: (90, 15)
# Extracted metrics for case_studies_exp_diabetes_cs2_w_acc_0_75_w_stab_0_25
#
# Extracting metrics for case_studies_exp_diabetes_cs3_w_acc_0_25_w_fair_0_25_w_stab_0_5...
# best_pps_per_lp_and_run_num_df.shape: (198, 15)
# best_lp_per_run_all.shape: (90, 15)
# Extracted metrics for case_studies_exp_diabetes_cs3_w_acc_0_25_w_fair_0_25_w_stab_0_5
#
# Extracting metrics for case_studies_exp_diabetes_cs3_w_acc_0_25_w_fair_0_5_w_stab_0_25...
# best_pps_per_lp_and_run_num_df.shape: (252, 15)
# best_lp_per_run_all.shape: (90, 15)
# Extracted metrics for case_studies_exp_diabetes_cs3_w_acc_0_25_w_fair_0_5_w_stab_0_25
#
# Extracting metrics for case_studies_exp_diabetes_cs3_w_acc_0_5_w_fair_0_25_w_stab_0_25...
# best_pps_per_lp_and_run_num_df.shape: (198, 15)
# best_lp_per_run_all.shape: (90, 15)
# Extracted metrics for case_studies_exp_diabetes_cs3_w_acc_0_5_w_fair_0_25_w_stab_0_25
#
# Extracting metrics for case_studies_exp_diabetes_cs3_w_acc_0_33_w_fair_0_33_w_stab_0_33...
# best_pps_per_lp_and_run_num_df.shape: (108, 15)
# best_lp_per_run_all.shape: (90, 15)
# Extracted metrics for case_studies_exp_diabetes_cs3_w_acc_0_33_w_fair_0_33_w_stab_0_33

# %%
best_lp_metrics_per_exp_config_df.shape
# Out:
# (783, 15)

# %%
best_lp_metrics_per_exp_config_df.head()
# Out:
# subgroup                                    exp_config_name  run_num  \
# 0         case_studies_exp_diabetes_cs1_w_acc_0_25_w_fai...        1
# 1         case_studies_exp_diabetes_cs1_w_acc_0_25_w_fai...        1
# 2         case_studies_exp_diabetes_cs1_w_acc_0_25_w_fai...        1
# 3         case_studies_exp_diabetes_cs1_w_acc_0_25_w_fai...        1
# 4         case_studies_exp_diabetes_cs1_w_acc_0_25_w_fai...        1
#
# subgroup                              logical_pipeline_uuid  \
# 0         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 1         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 2         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 3         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 4         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
#
# subgroup                physical_pipeline_uuid  compound_pp_quality    metric  \
# 0         608f0e8b-b164-4a5a-8fa2-7ee44be8b464             0.961379  Accuracy
# 1         608f0e8b-b164-4a5a-8fa2-7ee44be8b464             0.961379        F1
# 2         608f0e8b-b164-4a5a-8fa2-7ee44be8b464             0.961379       FNR
# 3         608f0e8b-b164-4a5a-8fa2-7ee44be8b464             0.961379       FPR
# 4         608f0e8b-b164-4a5a-8fa2-7ee44be8b464             0.961379       PPV
#
# subgroup   model_name  runtime_in_mins dataset_name  \
# 0         gandalf_clf         0.092335     diabetes
# 1         gandalf_clf         0.092335     diabetes
# 2         gandalf_clf         0.092335     diabetes
# 3         gandalf_clf         0.092335     diabetes
# 4         gandalf_clf         0.092335     diabetes
#
# subgroup                      logical_pipeline_name null_imputer_name  \
# 0         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 1         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 2         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 3         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 4         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
#
# subgroup fairness_intervention_name  Gender_dis  Gender_priv   overall
# 0          NO_FAIRNESS_INTERVENTION    0.916667     0.926829  0.922794
# 1          NO_FAIRNESS_INTERVENTION    0.880000     0.886792  0.883978
# 2          NO_FAIRNESS_INTERVENTION    0.083333     0.096154  0.090909
# 3          NO_FAIRNESS_INTERVENTION    0.083333     0.062500  0.070652
# 4          NO_FAIRNESS_INTERVENTION    0.846154     0.870370  0.860215

# %% [markdown]
# ## Get the best lp per exp config

# %%
# Get best lp per exp config
sqldf("""
    SELECT DISTINCT exp_config_name, logical_pipeline_name
    FROM best_lp_metrics_per_exp_config_df
""").to_df()
# Out:
#                                       exp_config_name  \
# 0   case_studies_exp_diabetes_cs1_w_acc_0_75_w_fai...
# 1   case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair...
# 2   case_studies_exp_diabetes_cs2_w_acc_0_75_w_sta...
# 3   case_studies_exp_diabetes_cs1_w_acc_0_25_w_fai...
# 4   case_studies_exp_diabetes_cs3_w_acc_0_25_w_fai...
# 5   case_studies_exp_diabetes_cs3_w_acc_0_33_w_fai...
# 6   case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair...
# 7   case_studies_exp_diabetes_cs1_w_acc_0_75_w_fai...
# 8   case_studies_exp_diabetes_cs2_w_acc_0_25_w_sta...
# 9   case_studies_exp_diabetes_cs2_w_acc_0_25_w_sta...
# 10  case_studies_exp_diabetes_cs3_w_acc_0_5_w_fair...
# 11  case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair...
# 12  case_studies_exp_diabetes_cs1_w_acc_0_75_w_fai...
# 13  case_studies_exp_diabetes_cs2_w_acc_0_25_w_sta...
# 14  case_studies_exp_diabetes_cs2_w_acc_0_5_w_stab...
# 15  case_studies_exp_diabetes_cs3_w_acc_0_5_w_fair...
# 16  case_studies_exp_diabetes_cs1_w_acc_0_25_w_fai...
# 17  case_studies_exp_diabetes_cs1_w_acc_0_25_w_fai...
# 18  case_studies_exp_diabetes_cs3_w_acc_0_25_w_fai...
#
#                         logical_pipeline_name
# 0   None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 1   None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 2        None&NO_FAIRNESS_INTERVENTION&rf_clf
# 3   None&NO_FAIRNESS_INTERVENTION&gandalf_clf
# 4        None&NO_FAIRNESS_INTERVENTION&rf_clf
# 5        None&NO_FAIRNESS_INTERVENTION&rf_clf
# 6        None&NO_FAIRNESS_INTERVENTION&rf_clf
# 7      None&NO_FAIRNESS_INTERVENTION&lgbm_clf
# 8        None&NO_FAIRNESS_INTERVENTION&lr_clf
# 9      None&NO_FAIRNESS_INTERVENTION&lgbm_clf
# 10       None&NO_FAIRNESS_INTERVENTION&rf_clf
# 11     None&NO_FAIRNESS_INTERVENTION&lgbm_clf
# 12       None&NO_FAIRNESS_INTERVENTION&rf_clf
# 13       None&NO_FAIRNESS_INTERVENTION&rf_clf
# 14       None&NO_FAIRNESS_INTERVENTION&rf_clf
# 15     None&NO_FAIRNESS_INTERVENTION&lgbm_clf
# 16       None&NO_FAIRNESS_INTERVENTION&rf_clf
# 17     None&NO_FAIRNESS_INTERVENTION&lgbm_clf
# 18       None&NO_FAIRNESS_INTERVENTION&rf_clf

# %% [markdown]
# ## Case study 1

# %%
CASE_STUDY_NAME = 'cs1'

# %%
to_plot = best_lp_metrics_per_exp_config_df
to_plot[(to_plot['dataset_name'] == DATASET_NAME) & (to_plot['exp_config_name'].str.contains(CASE_STUDY_NAME, case=False, na=False))]
# Out:
# subgroup                                    exp_config_name  run_num  \
# 0         case_studies_exp_diabetes_cs1_w_acc_0_25_w_fai...        1
# 1         case_studies_exp_diabetes_cs1_w_acc_0_25_w_fai...        1
# 2         case_studies_exp_diabetes_cs1_w_acc_0_25_w_fai...        1
# 3         case_studies_exp_diabetes_cs1_w_acc_0_25_w_fai...        1
# 4         case_studies_exp_diabetes_cs1_w_acc_0_25_w_fai...        1
# ..                                                      ...      ...
# 112       case_studies_exp_diabetes_cs1_w_acc_0_75_w_fai...        5
# 113       case_studies_exp_diabetes_cs1_w_acc_0_75_w_fai...        5
# 114       case_studies_exp_diabetes_cs1_w_acc_0_75_w_fai...        5
# 115       case_studies_exp_diabetes_cs1_w_acc_0_75_w_fai...        5
# 116       case_studies_exp_diabetes_cs1_w_acc_0_75_w_fai...        5
#
# subgroup                              logical_pipeline_uuid  \
# 0         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 1         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 2         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 3         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# 4         Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mZ2FuZG...
# ..                                                      ...
# 112        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 113        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 114        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 115        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 116        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
#
# subgroup                physical_pipeline_uuid  compound_pp_quality  \
# 0         608f0e8b-b164-4a5a-8fa2-7ee44be8b464             0.961379
# 1         608f0e8b-b164-4a5a-8fa2-7ee44be8b464             0.961379
# 2         608f0e8b-b164-4a5a-8fa2-7ee44be8b464             0.961379
# 3         608f0e8b-b164-4a5a-8fa2-7ee44be8b464             0.961379
# 4         608f0e8b-b164-4a5a-8fa2-7ee44be8b464             0.961379
# ..                                         ...                  ...
# 112       b952501d-7864-4458-88f2-1ed912eeeb66             0.967813
# 113       b952501d-7864-4458-88f2-1ed912eeeb66             0.967813
# 114       b952501d-7864-4458-88f2-1ed912eeeb66             0.967813
# 115       b952501d-7864-4458-88f2-1ed912eeeb66             0.967813
# 116       b952501d-7864-4458-88f2-1ed912eeeb66             0.967813
#
# subgroup          metric   model_name  runtime_in_mins dataset_name  \
# 0               Accuracy  gandalf_clf         0.092335     diabetes
# 1                     F1  gandalf_clf         0.092335     diabetes
# 2                    FNR  gandalf_clf         0.092335     diabetes
# 3                    FPR  gandalf_clf         0.092335     diabetes
# 4                    PPV  gandalf_clf         0.092335     diabetes
# ..                   ...          ...              ...          ...
# 112                  PPV       rf_clf         0.007789     diabetes
# 113          Sample_Size       rf_clf         0.007789     diabetes
# 114       Selection-Rate       rf_clf         0.007789     diabetes
# 115                  TNR       rf_clf         0.007789     diabetes
# 116                  TPR       rf_clf         0.007789     diabetes
#
# subgroup                      logical_pipeline_name null_imputer_name  \
# 0         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 1         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 2         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 3         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# 4         None&NO_FAIRNESS_INTERVENTION&gandalf_clf              None
# ..                                              ...               ...
# 112            None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 113            None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 114            None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 115            None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 116            None&NO_FAIRNESS_INTERVENTION&rf_clf              None
#
# subgroup fairness_intervention_name  Gender_dis  Gender_priv     overall
# 0          NO_FAIRNESS_INTERVENTION    0.916667     0.926829    0.922794
# 1          NO_FAIRNESS_INTERVENTION    0.880000     0.886792    0.883978
# 2          NO_FAIRNESS_INTERVENTION    0.083333     0.096154    0.090909
# 3          NO_FAIRNESS_INTERVENTION    0.083333     0.062500    0.070652
# 4          NO_FAIRNESS_INTERVENTION    0.846154     0.870370    0.860215
# ..                              ...         ...          ...         ...
# 112        NO_FAIRNESS_INTERVENTION    0.970588     0.930233    0.948052
# 113        NO_FAIRNESS_INTERVENTION  107.000000   165.000000  272.000000
# 114        NO_FAIRNESS_INTERVENTION    0.317757     0.260606    0.283088
# 115        NO_FAIRNESS_INTERVENTION    0.986301     0.976000    0.979798
# 116        NO_FAIRNESS_INTERVENTION    0.970588     1.000000    0.986486
#
# [153 rows x 15 columns]

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="F1")
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Equalized_Odds_TPR",
                                           group=GROUP)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Case study 2

# %%
CASE_STUDY_NAME = 'cs2'

# %%
to_plot = best_lp_metrics_per_exp_config_df
to_plot[(to_plot['dataset_name'] == DATASET_NAME) & (to_plot['exp_config_name'].str.contains(CASE_STUDY_NAME, case=False, na=False))]
# Out:
# subgroup                                    exp_config_name  run_num  \
# 18        case_studies_exp_diabetes_cs2_w_acc_0_25_w_sta...        1
# 19        case_studies_exp_diabetes_cs2_w_acc_0_25_w_sta...        1
# 20        case_studies_exp_diabetes_cs2_w_acc_0_25_w_sta...        1
# 21        case_studies_exp_diabetes_cs2_w_acc_0_25_w_sta...        1
# 22        case_studies_exp_diabetes_cs2_w_acc_0_25_w_sta...        1
# ..                                                      ...      ...
# 175       case_studies_exp_diabetes_cs2_w_acc_0_75_w_sta...        5
# 176       case_studies_exp_diabetes_cs2_w_acc_0_75_w_sta...        5
# 177       case_studies_exp_diabetes_cs2_w_acc_0_75_w_sta...        5
# 178       case_studies_exp_diabetes_cs2_w_acc_0_75_w_sta...        5
# 179       case_studies_exp_diabetes_cs2_w_acc_0_75_w_sta...        5
#
# subgroup                             logical_pipeline_uuid  \
# 18        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 19        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 20        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 21        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 22        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# ..                                                     ...
# 175       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 176       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 177       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 178       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 179       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
#
# subgroup                physical_pipeline_uuid  compound_pp_quality  \
# 18        8939878e-64d4-4d42-81cf-7eeedbae286f              0.93469
# 19        8939878e-64d4-4d42-81cf-7eeedbae286f              0.93469
# 20        8939878e-64d4-4d42-81cf-7eeedbae286f              0.93469
# 21        8939878e-64d4-4d42-81cf-7eeedbae286f              0.93469
# 22        8939878e-64d4-4d42-81cf-7eeedbae286f              0.93469
# ..                                         ...                  ...
# 175       7fa89018-728c-438b-bbe3-7eff626ca6d3              0.93073
# 176       7fa89018-728c-438b-bbe3-7eff626ca6d3              0.93073
# 177       7fa89018-728c-438b-bbe3-7eff626ca6d3              0.93073
# 178       7fa89018-728c-438b-bbe3-7eff626ca6d3              0.93073
# 179       7fa89018-728c-438b-bbe3-7eff626ca6d3              0.93073
#
# subgroup                 metric model_name  runtime_in_mins dataset_name  \
# 18                     Accuracy     rf_clf         0.366247     diabetes
# 19        Aleatoric_Uncertainty     rf_clf         0.366247     diabetes
# 20        Epistemic_Uncertainty     rf_clf         0.366247     diabetes
# 21                           F1     rf_clf         0.366247     diabetes
# 22                          FNR     rf_clf         0.366247     diabetes
# ..                          ...        ...              ...          ...
# 175              Selection-Rate     rf_clf         0.634681     diabetes
# 176            Statistical_Bias     rf_clf         0.634681     diabetes
# 177                         Std     rf_clf         0.634681     diabetes
# 178                         TNR     rf_clf         0.634681     diabetes
# 179                         TPR     rf_clf         0.634681     diabetes
#
# subgroup                 logical_pipeline_name null_imputer_name  \
# 18        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 19        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 20        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 21        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 22        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# ..                                         ...               ...
# 175       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 176       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 177       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 178       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 179       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
#
# subgroup fairness_intervention_name  Gender_dis  Gender_priv   overall
# 18         NO_FAIRNESS_INTERVENTION    0.972222     0.945122  0.955882
# 19         NO_FAIRNESS_INTERVENTION    0.174248     0.135068  0.150625
# 20         NO_FAIRNESS_INTERVENTION    0.085655     0.111047  0.100965
# 21         NO_FAIRNESS_INTERVENTION    0.957746     0.910891  0.930233
# 22         NO_FAIRNESS_INTERVENTION    0.055556     0.115385  0.090909
# ..                              ...         ...          ...       ...
# 175        NO_FAIRNESS_INTERVENTION    0.345794     0.272727  0.301471
# 176        NO_FAIRNESS_INTERVENTION    0.132866     0.114745  0.121874
# 177        NO_FAIRNESS_INTERVENTION    0.083667     0.090630  0.087891
# 178        NO_FAIRNESS_INTERVENTION    0.958904     0.960000  0.959596
# 179        NO_FAIRNESS_INTERVENTION    1.000000     1.000000  1.000000
#
# [270 rows x 15 columns]

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="F1")
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Label_Stability")
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Equalized_Odds_TPR",
                                           group=GROUP)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Case study 3

# %%
CASE_STUDY_NAME = 'cs3'

# %%
to_plot = best_lp_metrics_per_exp_config_df
to_plot[(to_plot['dataset_name'] == DATASET_NAME) & (to_plot['exp_config_name'].str.contains(CASE_STUDY_NAME, case=False, na=False))]
# Out:
# subgroup                                    exp_config_name  run_num  \
# 18        case_studies_exp_diabetes_cs3_w_acc_0_25_w_fai...        1
# 19        case_studies_exp_diabetes_cs3_w_acc_0_25_w_fai...        1
# 20        case_studies_exp_diabetes_cs3_w_acc_0_25_w_fai...        1
# 21        case_studies_exp_diabetes_cs3_w_acc_0_25_w_fai...        1
# 22        case_studies_exp_diabetes_cs3_w_acc_0_25_w_fai...        1
# ..                                                      ...      ...
# 103       case_studies_exp_diabetes_cs3_w_acc_0_33_w_fai...        5
# 104       case_studies_exp_diabetes_cs3_w_acc_0_33_w_fai...        5
# 105       case_studies_exp_diabetes_cs3_w_acc_0_33_w_fai...        5
# 106       case_studies_exp_diabetes_cs3_w_acc_0_33_w_fai...        5
# 107       case_studies_exp_diabetes_cs3_w_acc_0_33_w_fai...        5
#
# subgroup                             logical_pipeline_uuid  \
# 18        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 19        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 20        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 21        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 22        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# ..                                                     ...
# 103       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 104       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 105       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 106       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 107       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
#
# subgroup                physical_pipeline_uuid  compound_pp_quality  \
# 18        7dbfe994-65d4-431f-b832-d6262564fe40             0.935689
# 19        7dbfe994-65d4-431f-b832-d6262564fe40             0.935689
# 20        7dbfe994-65d4-431f-b832-d6262564fe40             0.935689
# 21        7dbfe994-65d4-431f-b832-d6262564fe40             0.935689
# 22        7dbfe994-65d4-431f-b832-d6262564fe40             0.935689
# ..                                         ...                  ...
# 103       0f53c2f7-ef51-4d34-aac1-25c31577e5e5             0.932409
# 104       0f53c2f7-ef51-4d34-aac1-25c31577e5e5             0.932409
# 105       0f53c2f7-ef51-4d34-aac1-25c31577e5e5             0.932409
# 106       0f53c2f7-ef51-4d34-aac1-25c31577e5e5             0.932409
# 107       0f53c2f7-ef51-4d34-aac1-25c31577e5e5             0.932409
#
# subgroup                 metric model_name  runtime_in_mins dataset_name  \
# 18                     Accuracy     rf_clf         0.359640     diabetes
# 19        Aleatoric_Uncertainty     rf_clf         0.359640     diabetes
# 20        Epistemic_Uncertainty     rf_clf         0.359640     diabetes
# 21                           F1     rf_clf         0.359640     diabetes
# 22                          FNR     rf_clf         0.359640     diabetes
# ..                          ...        ...              ...          ...
# 103              Selection-Rate     rf_clf         0.629229     diabetes
# 104            Statistical_Bias     rf_clf         0.629229     diabetes
# 105                         Std     rf_clf         0.629229     diabetes
# 106                         TNR     rf_clf         0.629229     diabetes
# 107                         TPR     rf_clf         0.629229     diabetes
#
# subgroup                 logical_pipeline_name null_imputer_name  \
# 18        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 19        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 20        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 21        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 22        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# ..                                         ...               ...
# 103       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 104       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 105       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 106       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 107       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
#
# subgroup fairness_intervention_name  Gender_dis  Gender_priv   overall
# 18         NO_FAIRNESS_INTERVENTION    0.972222     0.945122  0.955882
# 19         NO_FAIRNESS_INTERVENTION    0.174248     0.135068  0.150625
# 20         NO_FAIRNESS_INTERVENTION    0.085655     0.111047  0.100965
# 21         NO_FAIRNESS_INTERVENTION    0.957746     0.910891  0.930233
# 22         NO_FAIRNESS_INTERVENTION    0.055556     0.115385  0.090909
# ..                              ...         ...          ...       ...
# 103        NO_FAIRNESS_INTERVENTION    0.345794     0.272727  0.301471
# 104        NO_FAIRNESS_INTERVENTION    0.132870     0.114747  0.121876
# 105        NO_FAIRNESS_INTERVENTION    0.083670     0.090630  0.087892
# 106        NO_FAIRNESS_INTERVENTION    0.958904     0.960000  0.959596
# 107        NO_FAIRNESS_INTERVENTION    1.000000     1.000000  1.000000
#
# [360 rows x 15 columns]

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="F1")
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Equalized_Odds_TPR",
                                           group=GROUP)
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Label_Stability")
# Out:
# alt.Chart(...)
