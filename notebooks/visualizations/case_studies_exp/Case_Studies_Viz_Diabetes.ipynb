# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings

warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "virny-flow-experiments":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/Research/NYU/VirnyFlow_Project/Code/virny-flow-experiments

# %% [markdown]
# # Case Studies Visualizations

# %%
from duckdb import query as sqldf
from source.visualizations.use_case_queries import get_best_lps_per_exp_config
from source.visualizations.cost_model_viz import create_box_plot_per_dataset_and_case_study

# %% [markdown]
# ## Prepare data for visualizations

# %%
SECRETS_PATH = os.path.join(os.getcwd(), "scripts", "configs", "secrets.env")
EXP_NAME = 'case_studies_exp'
DATASET_NAME = 'diabetes'
GROUP = "Gender"
EXP_CONFIG_NAMES = [
    # "test_case_studies_exp_diabetes_cs1_w_acc_0_25_w_fair_0_75",
    # "test_case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair_0_5",
    # "test_case_studies_exp_diabetes_cs1_w_acc_0_75_w_fair_0_25",
    # "test_case_studies_exp_diabetes_cs2_w_acc_0_5_w_stab_0_5",
    
    "case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair_0_5",
    "case_studies_exp_diabetes_cs1_w_acc_0_25_w_fair_0_75",
    "case_studies_exp_diabetes_cs1_w_acc_0_75_w_fair_0_25",
    
    "case_studies_exp_diabetes_cs2_w_acc_0_25_w_stab_0_75",
    "case_studies_exp_diabetes_cs2_w_acc_0_5_w_stab_0_5",
    "case_studies_exp_diabetes_cs2_w_acc_0_75_w_stab_0_25",

    "case_studies_exp_diabetes_cs3_w_acc_0_25_w_fair_0_25_w_stab_0_5",
    "case_studies_exp_diabetes_cs3_w_acc_0_25_w_fair_0_5_w_stab_0_25",
    "case_studies_exp_diabetes_cs3_w_acc_0_5_w_fair_0_25_w_stab_0_25",
]

# %%
best_lp_metrics_per_exp_config_df = get_best_lps_per_exp_config(secrets_path=SECRETS_PATH, exp_config_names=EXP_CONFIG_NAMES)
# Out:
# Extracting metrics for case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair_0_5...
# best_pps_per_lp_and_run_num_df.shape: (90, 15)
# max_lp_avg_compound_pp_quality: 0.8600931047436571
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# Extracted metrics for case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair_0_5
#
# Extracting metrics for case_studies_exp_diabetes_cs1_w_acc_0_25_w_fair_0_75...
# best_pps_per_lp_and_run_num_df.shape: (90, 15)
# max_lp_avg_compound_pp_quality: 0.8851797809976313
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# Extracted metrics for case_studies_exp_diabetes_cs1_w_acc_0_25_w_fair_0_75
#
# Extracting metrics for case_studies_exp_diabetes_cs1_w_acc_0_75_w_fair_0_25...
# best_pps_per_lp_and_run_num_df.shape: (99, 15)
# max_lp_avg_compound_pp_quality: 0.8957443166085873
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# Extracted metrics for case_studies_exp_diabetes_cs1_w_acc_0_75_w_fair_0_25
#
# Extracting metrics for case_studies_exp_diabetes_cs2_w_acc_0_25_w_stab_0_75...
# best_pps_per_lp_and_run_num_df.shape: (198, 15)
# max_lp_avg_compound_pp_quality: 0.9043120352691528
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# Extracted metrics for case_studies_exp_diabetes_cs2_w_acc_0_25_w_stab_0_75
#
# Extracting metrics for case_studies_exp_diabetes_cs2_w_acc_0_5_w_stab_0_5...
# best_pps_per_lp_and_run_num_df.shape: (252, 15)
# max_lp_avg_compound_pp_quality: 0.8931852349730036
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# Extracted metrics for case_studies_exp_diabetes_cs2_w_acc_0_5_w_stab_0_5
#
# Extracting metrics for case_studies_exp_diabetes_cs2_w_acc_0_75_w_stab_0_25...
# best_pps_per_lp_and_run_num_df.shape: (234, 15)
# max_lp_avg_compound_pp_quality: 0.8796356493518488
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# Extracted metrics for case_studies_exp_diabetes_cs2_w_acc_0_75_w_stab_0_25
#
# Extracting metrics for case_studies_exp_diabetes_cs3_w_acc_0_25_w_fair_0_25_w_stab_0_5...
# best_pps_per_lp_and_run_num_df.shape: (270, 15)
# max_lp_avg_compound_pp_quality: 0.8850330190912664
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# Extracted metrics for case_studies_exp_diabetes_cs3_w_acc_0_25_w_fair_0_25_w_stab_0_5
#
# Extracting metrics for case_studies_exp_diabetes_cs3_w_acc_0_25_w_fair_0_5_w_stab_0_25...
# best_pps_per_lp_and_run_num_df.shape: (252, 15)
# max_lp_avg_compound_pp_quality: 0.8621445034009628
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# Extracted metrics for case_studies_exp_diabetes_cs3_w_acc_0_25_w_fair_0_5_w_stab_0_25
#
# Extracting metrics for case_studies_exp_diabetes_cs3_w_acc_0_5_w_fair_0_25_w_stab_0_25...
# best_pps_per_lp_and_run_num_df.shape: (234, 15)
# max_lp_avg_compound_pp_quality: 0.8731051456255833
# best_logical_pipeline_uuid: Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# Extracted metrics for case_studies_exp_diabetes_cs3_w_acc_0_5_w_fair_0_25_w_stab_0_25

# %%
best_lp_metrics_per_exp_config_df.shape
# Out:
# (621, 15)

# %%
best_lp_metrics_per_exp_config_df.head()
# Out:
# subgroup                                    exp_config_name  \
# 54        case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair...
# 55        case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair...
# 56        case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair...
# 57        case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair...
# 58        case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair...
#
# subgroup                             logical_pipeline_uuid  \
# 54        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 55        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 56        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 57        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 58        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
#
# subgroup                physical_pipeline_uuid  run_num  compound_pp_quality  \
# 54        22e719a0-1ae0-43bf-b319-65211c790100        5             0.860897
# 55        22e719a0-1ae0-43bf-b319-65211c790100        5             0.860897
# 56        22e719a0-1ae0-43bf-b319-65211c790100        5             0.860897
# 57        22e719a0-1ae0-43bf-b319-65211c790100        5             0.860897
# 58        22e719a0-1ae0-43bf-b319-65211c790100        5             0.860897
#
# subgroup    metric model_name  runtime_in_mins dataset_name  \
# 54        Accuracy     rf_clf         0.018867     diabetes
# 55              F1     rf_clf         0.018867     diabetes
# 56             FNR     rf_clf         0.018867     diabetes
# 57             FPR     rf_clf         0.018867     diabetes
# 58             PPV     rf_clf         0.018867     diabetes
#
# subgroup                 logical_pipeline_name null_imputer_name  \
# 54        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 55        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 56        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 57        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 58        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
#
# subgroup fairness_intervention_name  Gender_dis  Gender_priv   overall
# 54         NO_FAIRNESS_INTERVENTION    0.943925     0.915152  0.926471
# 55         NO_FAIRNESS_INTERVENTION    0.918919     0.829268  0.871795
# 56         NO_FAIRNESS_INTERVENTION    0.000000     0.150000  0.081081
# 57         NO_FAIRNESS_INTERVENTION    0.082192     0.064000  0.070707
# 58         NO_FAIRNESS_INTERVENTION    0.850000     0.809524  0.829268

# %% [markdown]
# ## Get the best lp per exp config

# %%
# Get best lp per exp config
sqldf("""
    SELECT DISTINCT exp_config_name, logical_pipeline_name
    FROM best_lp_metrics_per_exp_config_df
""").to_df()
# Out:
#                                      exp_config_name  \
# 0  case_studies_exp_diabetes_cs3_w_acc_0_25_w_fai...
# 1  case_studies_exp_diabetes_cs1_w_acc_0_75_w_fai...
# 2  case_studies_exp_diabetes_cs2_w_acc_0_25_w_sta...
# 3  case_studies_exp_diabetes_cs2_w_acc_0_5_w_stab...
# 4  case_studies_exp_diabetes_cs3_w_acc_0_25_w_fai...
# 5  case_studies_exp_diabetes_cs2_w_acc_0_75_w_sta...
# 6  case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair...
# 7  case_studies_exp_diabetes_cs3_w_acc_0_5_w_fair...
# 8  case_studies_exp_diabetes_cs1_w_acc_0_25_w_fai...
#
#                   logical_pipeline_name
# 0  None&NO_FAIRNESS_INTERVENTION&rf_clf
# 1  None&NO_FAIRNESS_INTERVENTION&rf_clf
# 2  None&NO_FAIRNESS_INTERVENTION&rf_clf
# 3  None&NO_FAIRNESS_INTERVENTION&rf_clf
# 4  None&NO_FAIRNESS_INTERVENTION&rf_clf
# 5  None&NO_FAIRNESS_INTERVENTION&rf_clf
# 6  None&NO_FAIRNESS_INTERVENTION&rf_clf
# 7  None&NO_FAIRNESS_INTERVENTION&rf_clf
# 8  None&NO_FAIRNESS_INTERVENTION&rf_clf

# %% [markdown]
# ## Case study 1

# %%
CASE_STUDY_NAME = 'cs1'

# %%
to_plot = best_lp_metrics_per_exp_config_df
to_plot[(to_plot['dataset_name'] == DATASET_NAME) & (to_plot['exp_config_name'].str.contains(CASE_STUDY_NAME, case=False, na=False))]
# Out:
# subgroup                                    exp_config_name  \
# 54        case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair...
# 55        case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair...
# 56        case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair...
# 57        case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair...
# 58        case_studies_exp_diabetes_cs1_w_acc_0_5_w_fair...
# ..                                                      ...
# 94        case_studies_exp_diabetes_cs1_w_acc_0_75_w_fai...
# 95        case_studies_exp_diabetes_cs1_w_acc_0_75_w_fai...
# 96        case_studies_exp_diabetes_cs1_w_acc_0_75_w_fai...
# 97        case_studies_exp_diabetes_cs1_w_acc_0_75_w_fai...
# 98        case_studies_exp_diabetes_cs1_w_acc_0_75_w_fai...
#
# subgroup                             logical_pipeline_uuid  \
# 54        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 55        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 56        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 57        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 58        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# ..                                                     ...
# 94        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 95        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 96        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 97        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 98        Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
#
# subgroup                physical_pipeline_uuid  run_num  compound_pp_quality  \
# 54        22e719a0-1ae0-43bf-b319-65211c790100        5             0.860897
# 55        22e719a0-1ae0-43bf-b319-65211c790100        5             0.860897
# 56        22e719a0-1ae0-43bf-b319-65211c790100        5             0.860897
# 57        22e719a0-1ae0-43bf-b319-65211c790100        5             0.860897
# 58        22e719a0-1ae0-43bf-b319-65211c790100        5             0.860897
# ..                                         ...      ...                  ...
# 94        fae422c1-6c48-419b-b328-866dc38abd16        3             0.828274
# 95        fae422c1-6c48-419b-b328-866dc38abd16        3             0.828274
# 96        fae422c1-6c48-419b-b328-866dc38abd16        3             0.828274
# 97        fae422c1-6c48-419b-b328-866dc38abd16        3             0.828274
# 98        fae422c1-6c48-419b-b328-866dc38abd16        3             0.828274
#
# subgroup          metric model_name  runtime_in_mins dataset_name  \
# 54              Accuracy     rf_clf         0.018867     diabetes
# 55                    F1     rf_clf         0.018867     diabetes
# 56                   FNR     rf_clf         0.018867     diabetes
# 57                   FPR     rf_clf         0.018867     diabetes
# 58                   PPV     rf_clf         0.018867     diabetes
# ..                   ...        ...              ...          ...
# 94                   PPV     rf_clf         0.010977     diabetes
# 95           Sample_Size     rf_clf         0.010977     diabetes
# 96        Selection-Rate     rf_clf         0.010977     diabetes
# 97                   TNR     rf_clf         0.010977     diabetes
# 98                   TPR     rf_clf         0.010977     diabetes
#
# subgroup                 logical_pipeline_name null_imputer_name  \
# 54        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 55        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 56        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 57        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 58        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# ..                                         ...               ...
# 94        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 95        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 96        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 97        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 98        None&NO_FAIRNESS_INTERVENTION&rf_clf              None
#
# subgroup fairness_intervention_name  Gender_dis  Gender_priv     overall
# 54         NO_FAIRNESS_INTERVENTION    0.943925     0.915152    0.926471
# 55         NO_FAIRNESS_INTERVENTION    0.918919     0.829268    0.871795
# 56         NO_FAIRNESS_INTERVENTION    0.000000     0.150000    0.081081
# 57         NO_FAIRNESS_INTERVENTION    0.082192     0.064000    0.070707
# 58         NO_FAIRNESS_INTERVENTION    0.850000     0.809524    0.829268
# ..                              ...         ...          ...         ...
# 94         NO_FAIRNESS_INTERVENTION    0.935484     0.894737    0.913043
# 95         NO_FAIRNESS_INTERVENTION   98.000000   174.000000  272.000000
# 96         NO_FAIRNESS_INTERVENTION    0.316327     0.218391    0.253676
# 97         NO_FAIRNESS_INTERVENTION    0.970588     0.968254    0.969072
# 98         NO_FAIRNESS_INTERVENTION    0.966667     0.708333    0.807692
#
# [99 rows x 15 columns]

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="F1")
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Equalized_Odds_TPR",
                                           group=GROUP)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Case study 2

# %%
CASE_STUDY_NAME = 'cs2'

# %%
to_plot = best_lp_metrics_per_exp_config_df
to_plot[(to_plot['dataset_name'] == DATASET_NAME) & (to_plot['exp_config_name'].str.contains(CASE_STUDY_NAME, case=False, na=False))]
# Out:
# subgroup                                    exp_config_name  \
# 126       case_studies_exp_diabetes_cs2_w_acc_0_25_w_sta...
# 127       case_studies_exp_diabetes_cs2_w_acc_0_25_w_sta...
# 128       case_studies_exp_diabetes_cs2_w_acc_0_25_w_sta...
# 129       case_studies_exp_diabetes_cs2_w_acc_0_25_w_sta...
# 130       case_studies_exp_diabetes_cs2_w_acc_0_25_w_sta...
# ..                                                      ...
# 229       case_studies_exp_diabetes_cs2_w_acc_0_75_w_sta...
# 230       case_studies_exp_diabetes_cs2_w_acc_0_75_w_sta...
# 231       case_studies_exp_diabetes_cs2_w_acc_0_75_w_sta...
# 232       case_studies_exp_diabetes_cs2_w_acc_0_75_w_sta...
# 233       case_studies_exp_diabetes_cs2_w_acc_0_75_w_sta...
#
# subgroup                             logical_pipeline_uuid  \
# 126       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 127       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 128       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 129       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 130       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# ..                                                     ...
# 229       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 230       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 231       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 232       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 233       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
#
# subgroup                physical_pipeline_uuid  run_num  compound_pp_quality  \
# 126       454fb785-4587-428a-9136-887fcee0cef5        2             0.896062
# 127       454fb785-4587-428a-9136-887fcee0cef5        2             0.896062
# 128       454fb785-4587-428a-9136-887fcee0cef5        2             0.896062
# 129       454fb785-4587-428a-9136-887fcee0cef5        2             0.896062
# 130       454fb785-4587-428a-9136-887fcee0cef5        2             0.896062
# ..                                         ...      ...                  ...
# 229       7ad517ef-0f15-40f7-b38b-9858056fb7df        1             0.931057
# 230       7ad517ef-0f15-40f7-b38b-9858056fb7df        1             0.931057
# 231       7ad517ef-0f15-40f7-b38b-9858056fb7df        1             0.931057
# 232       7ad517ef-0f15-40f7-b38b-9858056fb7df        1             0.931057
# 233       7ad517ef-0f15-40f7-b38b-9858056fb7df        1             0.931057
#
# subgroup                 metric model_name  runtime_in_mins dataset_name  \
# 126                    Accuracy     rf_clf         0.136714     diabetes
# 127       Aleatoric_Uncertainty     rf_clf         0.136714     diabetes
# 128       Epistemic_Uncertainty     rf_clf         0.136714     diabetes
# 129                          F1     rf_clf         0.136714     diabetes
# 130                         FNR     rf_clf         0.136714     diabetes
# ..                          ...        ...              ...          ...
# 229              Selection-Rate     rf_clf         0.177673     diabetes
# 230            Statistical_Bias     rf_clf         0.177673     diabetes
# 231                         Std     rf_clf         0.177673     diabetes
# 232                         TNR     rf_clf         0.177673     diabetes
# 233                         TPR     rf_clf         0.177673     diabetes
#
# subgroup                 logical_pipeline_name null_imputer_name  \
# 126       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 127       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 128       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 129       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 130       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# ..                                         ...               ...
# 229       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 230       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 231       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 232       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 233       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
#
# subgroup fairness_intervention_name  Gender_dis  Gender_priv   overall
# 126        NO_FAIRNESS_INTERVENTION    0.932692     0.916667  0.922794
# 127        NO_FAIRNESS_INTERVENTION    0.511196     0.443191  0.469193
# 128        NO_FAIRNESS_INTERVENTION    0.035666     0.034283  0.034812
# 129        NO_FAIRNESS_INTERVENTION    0.898551     0.844444  0.867925
# 130        NO_FAIRNESS_INTERVENTION    0.060606     0.191489  0.137500
# ..                              ...         ...          ...       ...
# 229        NO_FAIRNESS_INTERVENTION    0.324074     0.298780  0.308824
# 230        NO_FAIRNESS_INTERVENTION    0.087649     0.111724  0.102165
# 231        NO_FAIRNESS_INTERVENTION    0.074708     0.086478  0.081805
# 232        NO_FAIRNESS_INTERVENTION    0.986111     0.973214  0.978261
# 233        NO_FAIRNESS_INTERVENTION    0.944444     0.884615  0.909091
#
# [252 rows x 15 columns]

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="F1")
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Label_Stability")
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Case study 3

# %%
CASE_STUDY_NAME = 'cs3'

# %%
to_plot = best_lp_metrics_per_exp_config_df
to_plot[(to_plot['dataset_name'] == DATASET_NAME) & (to_plot['exp_config_name'].str.contains(CASE_STUDY_NAME, case=False, na=False))]
# Out:
# subgroup                                    exp_config_name  \
# 180       case_studies_exp_diabetes_cs3_w_acc_0_25_w_fai...
# 181       case_studies_exp_diabetes_cs3_w_acc_0_25_w_fai...
# 182       case_studies_exp_diabetes_cs3_w_acc_0_25_w_fai...
# 183       case_studies_exp_diabetes_cs3_w_acc_0_25_w_fai...
# 184       case_studies_exp_diabetes_cs3_w_acc_0_25_w_fai...
# ..                                                      ...
# 229       case_studies_exp_diabetes_cs3_w_acc_0_5_w_fair...
# 230       case_studies_exp_diabetes_cs3_w_acc_0_5_w_fair...
# 231       case_studies_exp_diabetes_cs3_w_acc_0_5_w_fair...
# 232       case_studies_exp_diabetes_cs3_w_acc_0_5_w_fair...
# 233       case_studies_exp_diabetes_cs3_w_acc_0_5_w_fair...
#
# subgroup                             logical_pipeline_uuid  \
# 180       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 181       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 182       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 183       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 184       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# ..                                                     ...
# 229       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 230       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 231       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 232       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
# 233       Tm9uZSZOT19GQUlSTkVTU19JTlRFUlZFTlRJT04mcmZfY2xm
#
# subgroup                physical_pipeline_uuid  run_num  compound_pp_quality  \
# 180       0af052be-e301-4cb4-ac9b-337de0d1b9d3        2             0.886981
# 181       0af052be-e301-4cb4-ac9b-337de0d1b9d3        2             0.886981
# 182       0af052be-e301-4cb4-ac9b-337de0d1b9d3        2             0.886981
# 183       0af052be-e301-4cb4-ac9b-337de0d1b9d3        2             0.886981
# 184       0af052be-e301-4cb4-ac9b-337de0d1b9d3        2             0.886981
# ..                                         ...      ...                  ...
# 229       fc4b445d-65fe-4d02-ba04-7ec02d598577        2             0.877602
# 230       fc4b445d-65fe-4d02-ba04-7ec02d598577        2             0.877602
# 231       fc4b445d-65fe-4d02-ba04-7ec02d598577        2             0.877602
# 232       fc4b445d-65fe-4d02-ba04-7ec02d598577        2             0.877602
# 233       fc4b445d-65fe-4d02-ba04-7ec02d598577        2             0.877602
#
# subgroup                 metric model_name  runtime_in_mins dataset_name  \
# 180                    Accuracy     rf_clf         0.125752     diabetes
# 181       Aleatoric_Uncertainty     rf_clf         0.125752     diabetes
# 182       Epistemic_Uncertainty     rf_clf         0.125752     diabetes
# 183                          F1     rf_clf         0.125752     diabetes
# 184                         FNR     rf_clf         0.125752     diabetes
# ..                          ...        ...              ...          ...
# 229              Selection-Rate     rf_clf         0.126492     diabetes
# 230            Statistical_Bias     rf_clf         0.126492     diabetes
# 231                         Std     rf_clf         0.126492     diabetes
# 232                         TNR     rf_clf         0.126492     diabetes
# 233                         TPR     rf_clf         0.126492     diabetes
#
# subgroup                 logical_pipeline_name null_imputer_name  \
# 180       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 181       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 182       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 183       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 184       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# ..                                         ...               ...
# 229       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 230       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 231       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 232       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
# 233       None&NO_FAIRNESS_INTERVENTION&rf_clf              None
#
# subgroup fairness_intervention_name  Gender_dis  Gender_priv   overall
# 180        NO_FAIRNESS_INTERVENTION    0.932692     0.916667  0.922794
# 181        NO_FAIRNESS_INTERVENTION    0.511196     0.443191  0.469193
# 182        NO_FAIRNESS_INTERVENTION    0.035666     0.034283  0.034812
# 183        NO_FAIRNESS_INTERVENTION    0.898551     0.844444  0.867925
# 184        NO_FAIRNESS_INTERVENTION    0.060606     0.191489  0.137500
# ..                              ...         ...          ...       ...
# 229        NO_FAIRNESS_INTERVENTION    0.346154     0.255952  0.290441
# 230        NO_FAIRNESS_INTERVENTION    0.175238     0.165883  0.169460
# 231        NO_FAIRNESS_INTERVENTION    0.074920     0.068718  0.071089
# 232        NO_FAIRNESS_INTERVENTION    0.929577     0.958678  0.947917
# 233        NO_FAIRNESS_INTERVENTION    0.939394     0.808511  0.862500
#
# [270 rows x 15 columns]

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="F1")
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Equalized_Odds_TPR",
                                           group=GROUP)
# Out:
# alt.Chart(...)

# %%
create_box_plot_per_dataset_and_case_study(to_plot=best_lp_metrics_per_exp_config_df,
                                           exp_name=EXP_NAME,
                                           dataset_name=DATASET_NAME,
                                           case_study_name=CASE_STUDY_NAME,
                                           metric_name="Label_Stability")
# Out:
# alt.Chart(...)
